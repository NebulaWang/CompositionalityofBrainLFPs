# %%
# @title Package
from natsort import natsorted
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import scipy as sp
import scipy.signal as signal
import torchaudio
import math
from sklearn import svm

import torchvision
import torchvision.transforms as transforms
import torchaudio.models as audio_models

from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset

import time

lib_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project44/Code'
os.chdir(lib_dir)
print('library directory: ' + lib_dir)
from modules.networks_clf import *
from modules.signal import spectro_norm, lfp_spectro
from modules.data import *
from modules.metrics import accu_fun
# Out:
# library directory: /content/drive/MyDrive/Project/BrainRegionId/Project44/Code

# %%
# @title Load device
dtype = torch.float
# Check whether GPU is available
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# !nvidia-smi -L
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# Set the signal parameters
spectro_args = {
    'nfft':800,
    'power':1,
    'LFP_bound':[0, 500],
    'MUA_bound':[500, 2000],
    'spectro_img':[224, 28],
    'LFP_img':[56 * 4, 28],
    'MUA_img':[0, 28],
    'sampling_lfp':2500,
    'sampling_mua':5000,
    'Log':False,
}

dict_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project37/Data/dat'
acronym_list = acronym_list_gen(dict_dir)

# %%
def iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index0, coordinate_list):

    data_test = TensorDataset(brain_signal_lfp[test_ind,:], brain_region_index0[test_ind], coordinate_list[test_ind])

    test_iter = DataLoader(data_test, batch_size=128, shuffle=True)

    return test_iter

# %%
def iter_subject_gen(train_ind, valid_ind, test_ind, test_subject_ind, brain_signal_lfp, brain_region_index0, coordinate_list):

    test_ind_od = test_subject_ind

    data_test = TensorDataset(brain_signal_lfp[test_ind_od,:], brain_region_index0[test_ind_od], coordinate_list[test_ind_od])

    test_iter_od = DataLoader(data_test, batch_size=128, shuffle=True)

    return test_iter_od

# %%
community_dict = torch.load('/content/drive/MyDrive/Project/BrainRegionId/Science/results/communities/StimOn/community_stimOn_dict.pt', weights_only=False)
communities_accu_indiv = torch.load('/content/drive/MyDrive/Project/BrainRegionId/Science/results/communities/StimOn/communities_stimOn_accu_indiv.pt', weights_only=False)
resolution = 1.0
marked_community = []
for community in np.unique(community_dict[resolution]['communities_label']):
    df_indiv0 = communities_accu_indiv[resolution][communities_accu_indiv[resolution]['acronym_test'] == community]
    for classifier_name in ['AnyNet']:
        if df_indiv0[df_indiv0['model_type'] == classifier_name]['acu_test'].mean() > 0.595:
            marked_community.append(community)

marked_community = np.unique(np.array(marked_community))

# %%
sns.set_theme(style='ticks', font_scale=1.3)
color_list = sns.color_palette('colorblind')
plt.figure(figsize=(12, 3), dpi=200)
g = sns.barplot(
    data=communities_accu_indiv[resolution],
    x='acronym_test', y='acu_test', hue='model_type',
    errorbar='sd', width=0.85, palette=color_list, alpha=.6
)
sns.move_legend(g, loc='lower center', bbox_to_anchor=(0.5, 1), ncol=3, title=None, fontsize=12)
plt.plot([-0.5, 34.5], [0.58, 0.58], 'k--')
plt.xlim([-0.5, 34.5])
plt.ylim([0, 1.1])
plt.xticks(marked_community)
plt.ylabel('cross-trial accuracy')
plt.xlabel('community index')
sns.despine()
# plt.title('StimOn')
# plt.legend(loc='lower left')
plt.show()
# Out:
# /tmp/ipython-input-601855737.py:4: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   g = sns.barplot(

# %%
for community_ii in np.unique(community_dict[1.0]['communities_label']):
    print(f'Commnity: {community_ii}')
    print('Allen:')
    print(community_dict[1.0]['communities_acronym'][np.argwhere(community_dict[1.0]['communities_label'] == community_ii).flatten()])
# Out:
# Commnity: 0
# Allen:
# ['SSp-bfd2/3' 'TEa2/3' 'TEa4']
# Commnity: 1
# Allen:
# ['FRP5' 'FRP6a' 'MOs5' 'MOs6a' 'MOs6b' 'SSp-n2/3' 'VISC6b' 'ACAd5'
#  'ACAd6a' 'ACAd6b' 'ACAv1' 'ACAv2/3' 'ACAv5' 'ACAv6a' 'ACAv6b' 'PL6a'
#  'PL6b' 'ILA6a' 'AIp6b' 'IG' 'CP']
# Commnity: 2
# Allen:
# ['MOp5' 'MOp6a' 'MOp6b' 'SSp-n4' 'SSp-n6a' 'SSp-n6b' 'SSp-m6a' 'SSp-m6b'
#  'ORBl5' 'ORBl6a' 'AId6a' 'AId6b' 'AIv5' 'AIv6a' 'AIv6b' 'CLA']
# Commnity: 3
# Allen:
# ['LSc' 'LSr' 'LSv' 'SF' 'SH' 'TRS' 'SFO' 'BST']
# Commnity: 4
# Allen:
# ['PL5' 'ILA1' 'ILA2/3' 'ILA5' 'ORBm5' 'ORBm6a' 'ORBvl6a']
# Commnity: 5
# Allen:
# ['VISpm5' 'VISpm6a' 'VISpm6b' 'RSPd6b' 'RSPv6b']
# Commnity: 6
# Allen:
# ['SSs2/3' 'VISp2/3' 'VISpl6a' 'RSPv6a']
# Commnity: 7
# Allen:
# ['VISp1' 'VISp4' 'VISp5' 'VISpl5' 'VISpm1' 'VISpm2/3' 'VISpm4' 'RSPagl2/3'
#  'RSPagl5' 'RSPagl6a' 'RSPagl6b' 'RSPd1' 'RSPd2/3' 'RSPd5' 'RSPd6a'
#  'RSPv2/3' 'VISa2/3' 'VISa4' 'VISa5' 'VISa6b' 'APr' 'SCop' 'SCsg' 'SCzo'
#  'POST']
# Commnity: 8
# Allen:
# ['VISl1' 'VISl2/3' 'VISl4' 'VISl5' 'VISl6a' 'VISli2/3' 'VISli6b']
# Commnity: 9
# Allen:
# ['KF' 'DCO' 'ECU' 'SPVC' 'SPVI' 'Pa5' 'AMBv' 'DMX' 'GRN' 'ICB' 'IO' 'IRN'
#  'LIN' 'LRNm' 'MARN' 'MDRNd' 'MDRNv' 'PARN' 'PGRNd' 'PGRNl' 'PRP' 'LAV'
#  'MV' 'SPIV' 'SUV' 'x' 'y' 'FN' 'IP' 'DN' 'VeCB' 'NTS' 'SPVO' 'LING'
#  'CENT2' 'CENT3' 'CUL4 5' 'DEC' 'FOTU' 'PYR' 'UVU' 'NOD' 'SIM' 'ANcr2'
#  'PRM' 'COPY' 'PFL' 'FL']
# Commnity: 10
# Allen:
# ['VPL' 'VPLpc' 'VPM' 'PoT' 'SPFp' 'MGm' 'LP' 'PO' 'SGN' 'LD' 'PIL' 'STN'
#  'TU' 'FF' 'NB' 'SNr' 'SCdg' 'SCdw' 'SCiw' 'INC' 'ND' 'Su3' 'APN' 'NOT'
#  'NPC' 'OP' 'PPT' 'RPF' 'RN' 'III' 'Pa4' 'VTN' 'SNc' 'IF' 'IPA' 'IPDM'
#  'IPDL' 'RL' 'CLI' 'DR' 'MRN' 'CS']
# Commnity: 11
# Allen:
# ['ENTl3' 'ENTl5' 'PIR']
# Commnity: 12
# Allen:
# ['VISpor1' 'VISpor2/3' 'ENTm5' 'ENTm6' 'ANcr1']
# Commnity: 13
# Allen:
# ['EPv' 'BLAp' 'TR']
# Commnity: 14
# Allen:
# ['LA' 'BMAa' 'BMAp' 'FS' 'CEAc' 'CEAl' 'CEAm' 'IA' 'GPi' 'COAa' 'PAA'
#  'MEA']
# Commnity: 15
# Allen:
# ['SPFm' 'IAM' 'IMD' 'PVT' 'PT' 'RE' 'Xi' 'RH' 'PH' 'PVH' 'DMH' 'AHN' 'MPN'
#  'VMH']
# Commnity: 16
# Allen:
# ['SPA' 'PR' 'PRC' 'PVHd']
# Commnity: 17
# Allen:
# ['VAL' 'AV' 'SMT' 'PCN']
# Commnity: 18
# Allen:
# ['VM' 'VPMpc' 'MH' 'PeF']
# Commnity: 19
# Allen:
# ['SSp-tr2/3' 'SSp-tr4' 'SSp-tr5' 'SSp-tr6a' 'SSp-tr6b']
# Commnity: 20
# Allen:
# ['SSp-ll1' 'SSp-ll2/3' 'SSp-ll4' 'SSp-ll5' 'SSp-ll6a' 'SSp-ll6b' 'SSp-ul1'
#  'SSp-ul2/3' 'SSp-ul4' 'SSp-ul5' 'SSp-ul6a' 'SSp-ul6b']
# Commnity: 21
# Allen:
# ['AUDpo5' 'AUDpo6a' 'AUDv6a' 'VISal2/3' 'VISal4' 'VISal6a' 'VISal6b'
#  'VISrl1' 'VISrl2/3' 'VISrl5' 'VISrl6a' 'VISrl6b' 'TEa5' 'TEa6a' 'ECT2/3'
#  'ECT5']
# Commnity: 22
# Allen:
# ['SSp-m2/3' 'SSp-m4' 'SSp-m5' 'GU5' 'GU6a']
# Commnity: 23
# Allen:
# ['SSs6a' 'SSs6b' 'VISC6a' 'AIp1']
# Commnity: 24
# Allen:
# ['SSp-bfd4' 'SSs5' 'AUDd6a']
# Commnity: 25
# Allen:
# ['VISC5' 'AIp2/3' 'AIp5']
# Commnity: 26
# Allen:
# ['FRP1' 'FRP2/3' 'ORBl1' 'ORBl2/3' 'ORBvl1' 'ORBvl2/3' 'AOBgl' 'AOBmi'
#  'DG-mo' 'DG-po' 'DG-sg' 'AON' 'ProS']
# Commnity: 27
# Allen:
# ['ICe' 'CUN' 'NLL']
# Commnity: 28
# Allen:
# ['PSV' 'SUT' 'V' 'PC5']
# Commnity: 29
# Allen:
# ['MGv' 'LGd-co' 'LGd-ip' 'IGL']
# Commnity: 30
# Allen:
# ['PL1' 'PL2/3' 'ORBm1']
# Commnity: 31
# Allen:
# ['VISam1' 'VISam2/3' 'VISam4' 'VISam5' 'VISam6a' 'VISam6b']
# Commnity: 32
# Allen:
# ['AT' 'SOCm' 'PRNr']
# Commnity: 33
# Allen:
# ['AVP' 'MPO' 'PS' 'VLPO' 'LPO']
# Commnity: 34
# Allen:
# ['HATA' 'XII' 'RO']

# %%
################################################################################
import subprocess
import sys
required = {'ONE-api', 'brain', 'ibllib'}
subprocess.check_call([sys.executable, '-m', 'pip', 'install', *required])

from one.api import ONE
from brainbox.io.one import SessionLoader, SpikeSortingLoader

from iblatlas.atlas import AllenAtlas

ba = AllenAtlas()
br = ba.regions
ba.compute_regions_volume()
# Out:
# Downloading: /root/Downloads/ONE/openalyx.internationalbrainlab.org/histology/ATLAS/Needles/Allen/average_template_25.nrrd Bytes: 32998960
# 100%|██████████| 31.470260620117188/31.470260620117188 [00:01<00:00, 16.39it/s]
# Downloading: /root/Downloads/ONE/openalyx.internationalbrainlab.org/histology/ATLAS/Needles/Allen/annotation_25.nrrd Bytes: 4035363
# 100%|██████████| 3.848422050476074/3.848422050476074 [00:01<00:00,  3.85it/s]

# %%
community_dict[1.0]['communities']
# Out:
# array([ 21, 195, 196,   2,   3,  11,  12,  13,  15,  65, 127, 128, 129,
#        130, 131, 132, 133, 134, 138, 139, 143, 163, 213, 236,   6,   7,
#          8,  16,  18,  19,  36,  37, 146, 147, 157, 158, 165, 166, 167,
#        226, 239, 240, 241, 242, 243, 255, 308, 441, 137, 140, 141, 142,
#        150, 151, 155, 113, 114, 115, 177, 182,  56, 100, 109, 181,  99,
#        101, 102, 108, 110, 111, 112, 169, 170, 171, 172, 173, 174, 175,
#        176, 179, 184, 185, 186, 188, 225, 319, 320, 321, 435,  93,  94,
#         95,  96,  97, 116, 120, 366, 385, 388, 389, 390, 391, 393, 394,
#        395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 406, 407, 408,
#        409, 410, 411, 412, 413, 415, 417, 418, 419, 420, 454, 455, 456,
#        457, 458, 459, 460, 461, 462, 463, 464, 465, 467, 468, 469, 470,
#        471, 258, 259, 260, 262, 264, 269, 273, 274, 276, 284, 297, 316,
#        317, 318, 325, 328, 331, 332, 333, 335, 336, 337, 338, 340, 341,
#        342, 343, 344, 346, 347, 350, 351, 355, 357, 358, 360, 361, 362,
#        363, 364, 451, 453, 216, 217, 426, 121, 122, 222, 223, 466, 228,
#        231, 430, 229, 233, 234, 238, 245, 246, 247, 248, 250, 427, 429,
#        440, 263, 282, 285, 288, 289, 290, 291, 292, 312, 444, 445, 446,
#        448, 450, 265, 287, 334, 449, 256, 278, 286, 294, 257, 261, 302,
#        315,  45,  46,  47,  48,  49,  26,  27,  28,  29,  30,  31,  38,
#         39,  40,  41,  42,  43,  76,  77,  80,  82,  83,  85,  86, 189,
#        190, 192, 193, 194, 197, 198, 203, 204,  33,  34,  35,  61,  62,
#         59,  60,  64, 159,  22,  58,  69,  63, 160, 161,   0,   1, 144,
#        145, 152, 153, 207, 208, 209, 210, 211, 422, 438, 324, 345, 452,
#        365, 375, 377, 379, 268, 271, 272, 299, 135, 136, 148,  87,  88,
#         89,  90,  91,  92, 352, 368, 384, 305, 306, 307, 309, 314, 224,
#        414, 416])

# %%
acronym_list_Cosmos = [br.acronym2acronym(acronym, mapping='Cosmos')[0] for acronym in acronym_list]
acronym_list_Cosmos = np.array(acronym_list_Cosmos)
for community_ii in np.unique(community_dict[1.0]['communities_label']):
    print(f'Commnity: {community_ii}')
    print('Allen:')
    print(community_dict[1.0]['communities_acronym'][np.argwhere(community_dict[1.0]['communities_label'] == community_ii).flatten()])
    print('Cosmos:')
    print(acronym_list_Cosmos[community_dict[1.0]['communities'][np.argwhere(community_dict[1.0]['communities_label'] == community_ii).flatten()]])
# Out:
# Commnity: 0
# Allen:
# ['SSp-bfd2/3' 'TEa2/3' 'TEa4']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 1
# Allen:
# ['FRP5' 'FRP6a' 'MOs5' 'MOs6a' 'MOs6b' 'SSp-n2/3' 'VISC6b' 'ACAd5'
#  'ACAd6a' 'ACAd6b' 'ACAv1' 'ACAv2/3' 'ACAv5' 'ACAv6a' 'ACAv6b' 'PL6a'
#  'PL6b' 'ILA6a' 'AIp6b' 'IG' 'CP']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'HPF' 'CNU']
# Commnity: 2
# Allen:
# ['MOp5' 'MOp6a' 'MOp6b' 'SSp-n4' 'SSp-n6a' 'SSp-n6b' 'SSp-m6a' 'SSp-m6b'
#  'ORBl5' 'ORBl6a' 'AId6a' 'AId6b' 'AIv5' 'AIv6a' 'AIv6b' 'CLA']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'CTXsp']
# Commnity: 3
# Allen:
# ['LSc' 'LSr' 'LSv' 'SF' 'SH' 'TRS' 'SFO' 'BST']
# Cosmos:
# ['CNU' 'CNU' 'CNU' 'CNU' 'CNU' 'CNU' 'HY' 'CNU']
# Commnity: 4
# Allen:
# ['PL5' 'ILA1' 'ILA2/3' 'ILA5' 'ORBm5' 'ORBm6a' 'ORBvl6a']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex']
# Commnity: 5
# Allen:
# ['VISpm5' 'VISpm6a' 'VISpm6b' 'RSPd6b' 'RSPv6b']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 6
# Allen:
# ['SSs2/3' 'VISp2/3' 'VISpl6a' 'RSPv6a']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 7
# Allen:
# ['VISp1' 'VISp4' 'VISp5' 'VISpl5' 'VISpm1' 'VISpm2/3' 'VISpm4' 'RSPagl2/3'
#  'RSPagl5' 'RSPagl6a' 'RSPagl6b' 'RSPd1' 'RSPd2/3' 'RSPd5' 'RSPd6a'
#  'RSPv2/3' 'VISa2/3' 'VISa4' 'VISa5' 'VISa6b' 'APr' 'SCop' 'SCsg' 'SCzo'
#  'POST']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'HPF' 'MB' 'MB' 'MB' 'HPF']
# Commnity: 8
# Allen:
# ['VISl1' 'VISl2/3' 'VISl4' 'VISl5' 'VISl6a' 'VISli2/3' 'VISli6b']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex']
# Commnity: 9
# Allen:
# ['KF' 'DCO' 'ECU' 'SPVC' 'SPVI' 'Pa5' 'AMBv' 'DMX' 'GRN' 'ICB' 'IO' 'IRN'
#  'LIN' 'LRNm' 'MARN' 'MDRNd' 'MDRNv' 'PARN' 'PGRNd' 'PGRNl' 'PRP' 'LAV'
#  'MV' 'SPIV' 'SUV' 'x' 'y' 'FN' 'IP' 'DN' 'VeCB' 'NTS' 'SPVO' 'LING'
#  'CENT2' 'CENT3' 'CUL4 5' 'DEC' 'FOTU' 'PYR' 'UVU' 'NOD' 'SIM' 'ANcr2'
#  'PRM' 'COPY' 'PFL' 'FL']
# Cosmos:
# ['HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB'
#  'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'HB' 'CB'
#  'CB' 'CB' 'CB' 'HB' 'HB' 'CB' 'CB' 'CB' 'CB' 'CB' 'CB' 'CB' 'CB' 'CB'
#  'CB' 'CB' 'CB' 'CB' 'CB' 'CB']
# Commnity: 10
# Allen:
# ['VPL' 'VPLpc' 'VPM' 'PoT' 'SPFp' 'MGm' 'LP' 'PO' 'SGN' 'LD' 'PIL' 'STN'
#  'TU' 'FF' 'NB' 'SNr' 'SCdg' 'SCdw' 'SCiw' 'INC' 'ND' 'Su3' 'APN' 'NOT'
#  'NPC' 'OP' 'PPT' 'RPF' 'RN' 'III' 'Pa4' 'VTN' 'SNc' 'IF' 'IPA' 'IPDM'
#  'IPDL' 'RL' 'CLI' 'DR' 'MRN' 'CS']
# Cosmos:
# ['TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'HY' 'HY' 'HY'
#  'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB'
#  'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'MB' 'HB']
# Commnity: 11
# Allen:
# ['ENTl3' 'ENTl5' 'PIR']
# Cosmos:
# ['HPF' 'HPF' 'OLF']
# Commnity: 12
# Allen:
# ['VISpor1' 'VISpor2/3' 'ENTm5' 'ENTm6' 'ANcr1']
# Cosmos:
# ['Isocortex' 'Isocortex' 'HPF' 'HPF' 'CB']
# Commnity: 13
# Allen:
# ['EPv' 'BLAp' 'TR']
# Cosmos:
# ['CTXsp' 'CTXsp' 'OLF']
# Commnity: 14
# Allen:
# ['LA' 'BMAa' 'BMAp' 'FS' 'CEAc' 'CEAl' 'CEAm' 'IA' 'GPi' 'COAa' 'PAA'
#  'MEA']
# Cosmos:
# ['CTXsp' 'CTXsp' 'CTXsp' 'CNU' 'CNU' 'CNU' 'CNU' 'CNU' 'CNU' 'OLF' 'OLF'
#  'CNU']
# Commnity: 15
# Allen:
# ['SPFm' 'IAM' 'IMD' 'PVT' 'PT' 'RE' 'Xi' 'RH' 'PH' 'PVH' 'DMH' 'AHN' 'MPN'
#  'VMH']
# Cosmos:
# ['TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'TH' 'HY' 'HY' 'HY' 'HY' 'HY' 'HY']
# Commnity: 16
# Allen:
# ['SPA' 'PR' 'PRC' 'PVHd']
# Cosmos:
# ['TH' 'TH' 'MB' 'HY']
# Commnity: 17
# Allen:
# ['VAL' 'AV' 'SMT' 'PCN']
# Cosmos:
# ['TH' 'TH' 'TH' 'TH']
# Commnity: 18
# Allen:
# ['VM' 'VPMpc' 'MH' 'PeF']
# Cosmos:
# ['TH' 'TH' 'TH' 'HY']
# Commnity: 19
# Allen:
# ['SSp-tr2/3' 'SSp-tr4' 'SSp-tr5' 'SSp-tr6a' 'SSp-tr6b']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 20
# Allen:
# ['SSp-ll1' 'SSp-ll2/3' 'SSp-ll4' 'SSp-ll5' 'SSp-ll6a' 'SSp-ll6b' 'SSp-ul1'
#  'SSp-ul2/3' 'SSp-ul4' 'SSp-ul5' 'SSp-ul6a' 'SSp-ul6b']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 21
# Allen:
# ['AUDpo5' 'AUDpo6a' 'AUDv6a' 'VISal2/3' 'VISal4' 'VISal6a' 'VISal6b'
#  'VISrl1' 'VISrl2/3' 'VISrl5' 'VISrl6a' 'VISrl6b' 'TEa5' 'TEa6a' 'ECT2/3'
#  'ECT5']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 22
# Allen:
# ['SSp-m2/3' 'SSp-m4' 'SSp-m5' 'GU5' 'GU6a']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 23
# Allen:
# ['SSs6a' 'SSs6b' 'VISC6a' 'AIp1']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 24
# Allen:
# ['SSp-bfd4' 'SSs5' 'AUDd6a']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 25
# Allen:
# ['VISC5' 'AIp2/3' 'AIp5']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 26
# Allen:
# ['FRP1' 'FRP2/3' 'ORBl1' 'ORBl2/3' 'ORBvl1' 'ORBvl2/3' 'AOBgl' 'AOBmi'
#  'DG-mo' 'DG-po' 'DG-sg' 'AON' 'ProS']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex'
#  'OLF' 'OLF' 'HPF' 'HPF' 'HPF' 'OLF' 'HPF']
# Commnity: 27
# Allen:
# ['ICe' 'CUN' 'NLL']
# Cosmos:
# ['MB' 'MB' 'HB']
# Commnity: 28
# Allen:
# ['PSV' 'SUT' 'V' 'PC5']
# Cosmos:
# ['HB' 'HB' 'HB' 'HB']
# Commnity: 29
# Allen:
# ['MGv' 'LGd-co' 'LGd-ip' 'IGL']
# Cosmos:
# ['TH' 'TH' 'TH' 'TH']
# Commnity: 30
# Allen:
# ['PL1' 'PL2/3' 'ORBm1']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 31
# Allen:
# ['VISam1' 'VISam2/3' 'VISam4' 'VISam5' 'VISam6a' 'VISam6b']
# Cosmos:
# ['Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex' 'Isocortex']
# Commnity: 32
# Allen:
# ['AT' 'SOCm' 'PRNr']
# Cosmos:
# ['MB' 'HB' 'HB']
# Commnity: 33
# Allen:
# ['AVP' 'MPO' 'PS' 'VLPO' 'LPO']
# Cosmos:
# ['HY' 'HY' 'HY' 'HY' 'HY']
# Commnity: 34
# Allen:
# ['HATA' 'XII' 'RO']
# Cosmos:
# ['HPF' 'HB' 'HB']
