# %%
# @title Package
from natsort import natsorted
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import scipy as sp
import scipy.signal as signal
import torchaudio
import math
from sklearn import svm

import torchvision
import torchvision.transforms as transforms
import torchaudio.models as audio_models

from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset

import time

lib_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project44/Code'
os.chdir(lib_dir)
print('library directory: ' + lib_dir)
from modules.networks_clf import *
from modules.signal import spectro_norm, lfp_spectro
from modules.data import *
from modules.metrics import accu_fun
# Out:
# library directory: /content/drive/MyDrive/Project/BrainRegionId/Project44/Code

# %%
# @title Load device
dtype = torch.float
# Check whether GPU is available
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# !nvidia-smi -L

# %%
# Set the signal parameters
spectro_args = {
    'nfft':800,
    'power':1,
    'LFP_bound':[0, 500],
    'MUA_bound':[500, 2000],
    'spectro_img':[224, 28],
    'LFP_img':[56 * 4, 28],
    'MUA_img':[0, 28],
    'sampling_lfp':2500,
    'sampling_mua':5000,
    'Log':False,
}

dict_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project37/Data/dat'
acronym_list = acronym_list_gen(dict_dir)

# %%
# @title Load data
file_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project43/Data/dat/completed/'
brain_signal_lfp = torch.load('/content/drive/MyDrive/Project/BrainRegionId/Project43/Result/brain_signal_lfp/brain_signal_lfp.pt', weights_only=False)
list_dict = torch.load(file_dir + '/list_dict.pt', weights_only=False)

brain_region_index = list_dict['brain_region_index']
brain_region_index_Cosmos = list_dict['brain_region_index_Cosmos']
coordinate_list = list_dict['coordinate_list']
acronym_selec_list = list_dict['acronym_selec_list']

# %%
if len(brain_signal_lfp) == len(brain_region_index):
    print('Matched, no damage!')
# Out:
# Matched, no damage!

# %%
key = 'stimOff'
community_dict = torch.load(f'/content/drive/MyDrive/Project/BrainRegionId/Nature/results/communities/community_dict_1024_{key}.pt', weights_only=False)

# %%
def iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index0, coordinate_list):
    data_train = TensorDataset(brain_signal_lfp[train_ind,:], brain_region_index0[train_ind], coordinate_list[train_ind])
    data_valid = TensorDataset(brain_signal_lfp[valid_ind,:], brain_region_index0[valid_ind], coordinate_list[valid_ind])
    data_test = TensorDataset(brain_signal_lfp[test_ind,:], brain_region_index0[test_ind], coordinate_list[test_ind])

    train_iter = DataLoader(data_train, batch_size=128, shuffle=True)
    valid_iter = DataLoader(data_valid, batch_size=128, shuffle=True)
    test_iter = DataLoader(data_test, batch_size=128, shuffle=True)

    return train_iter, valid_iter, test_iter

# %%
# @title Training function
def net_train_AnyNet_L(train_iter, valid_iter, Classifier, spectro_args, train_args, key, ind, resolution, device):
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(Classifier.parameters(), train_args['lr'])
    # print('lr: ' + train_args['lr'])
    acu_array_train = []
    acu_array_valid = []
    time_array_train = []
    time_array_valid = []
    acu_valid_max = 0
    for epoch in range(0, train_args['epochs']):
        Classifier.train()
        acu_train = []
        epoch0 = 0
        time0_train = time.time()
        for x_train1, y_train, coordinate_train in train_iter:
            x_train = lfp_spectro(x_train1, spectro_args, train_args)
            y_train = y_train.to(device)
            py_train = Classifier(x_train.to(device))
            del x_train, x_train1
            if epoch0 % 800 == 0:
                if epoch0 == 0 and epoch == 0:
                    if accu_fun(py_train, y_train) == (torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu():
                        print('accu_fun is correct>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
                    else:
                        print('accu_fun is wrong>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
                        return
                print(accu_fun(py_train, y_train))
            # print(y_train.size())
            L = loss_fn(py_train,y_train.to(device))
            optimizer.zero_grad()
            L.backward()
            optimizer.step()
            acu_train.append(accu_fun(py_train, y_train))
            epoch0 += 1
        print(f'Acu Train: {torch.mean(torch.tensor(acu_train))}')

        acu_array_train.append(torch.mean(torch.tensor(acu_train)))
        time_array_train.append(time.time() - time0_train)

        Classifier.eval()
        acu_valid = []
        time0_valid = time.time()
        for x_valid1, y_valid, coordinate_valid in valid_iter:
            x_valid = lfp_spectro(x_valid1, spectro_args, train_args)
            y_valid = y_valid.to(device)
            py_valid = Classifier(x_valid.to(device))
            del x_valid, x_valid1
            acu_valid.append(accu_fun(py_valid, y_valid))
            # acu_valid.append((torch.sum(torch.argmax(py_valid, dim=1) == y_valid) / y_valid.size(0)).detach().cpu())

        print(f'Acu valid: {torch.mean(torch.tensor(acu_valid))}')
        if torch.mean(torch.tensor(acu_train)) > train_args['overfitting_thres']:
            if acu_valid_max < torch.mean(torch.tensor(acu_valid)):
                torch.save(Classifier, train_args['save_dir'] + f'/Model/Community/{resolution}/AnyNet_L_AllenCommunity_{key}_{ind}.pth')
                torch.save(epoch, train_args['save_dir'] + f'/Model/Community/{resolution}/AnyNet_L_AllenCommunity_{key}_epoch{ind}.pt')
                acu_valid_max = torch.mean(torch.tensor(acu_valid))

        acu_array_valid.append(torch.mean(torch.tensor(acu_valid)))
        time_array_valid.append(time.time() - time0_valid)

    torch.save(acu_array_train, train_args['save_dir'] + f'/Model/Community/{resolution}/AnyNet_L_AllenCommunity_{key}_train_acu{ind}.pt')
    torch.save(acu_array_valid, train_args['save_dir'] + f'/Model/Community/{resolution}/AnyNet_L_AllenCommunity_{key}_valid_acu{ind}.pt')

    return


def net_train_ViT_L(train_iter, valid_iter, Classifier, spectro_args, train_args, key, ind, resolution, device):
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(Classifier.parameters(), train_args['lr'])
    # print('lr: ' + train_args['lr'])
    acu_array_train = []
    acu_array_valid = []
    time_array_train = []
    time_array_valid = []
    acu_valid_max = 0
    for epoch in range(0, train_args['epochs']):
        Classifier.train()
        acu_train = []
        epoch0 = 0
        time0_train = time.time()
        for x_train1, y_train, coordinate_train in train_iter:
            x_train = lfp_spectro(x_train1, spectro_args, train_args)
            y_train = y_train.to(device)
            py_train = Classifier(x_train.to(device))
            del x_train, x_train1
            if epoch0 % 800 == 0:
                print((torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu())
            L = loss_fn(py_train,y_train.to(device))
            optimizer.zero_grad()
            L.backward()
            optimizer.step()
            acu_train.append((torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu())
            epoch0 += 1
        print(f'Acu Train: {torch.mean(torch.tensor(acu_train))}')

        acu_array_train.append(torch.mean(torch.tensor(acu_train)))
        time_array_train.append(time.time() - time0_train)

        Classifier.eval()
        acu_valid = []
        time0_valid = time.time()
        for x_valid1, y_valid, coordinate_valid in valid_iter:
            x_valid = lfp_spectro(x_valid1, spectro_args, train_args)
            y_valid = y_valid.to(device)
            py_valid = Classifier(x_valid.to(device))
            del x_valid, x_valid1
            acu_valid.append((torch.sum(torch.argmax(py_valid, dim=1) == y_valid) / y_valid.size(0)).detach().cpu())

        print(f'Acu valid: {torch.mean(torch.tensor(acu_valid))}')
        if torch.mean(torch.tensor(acu_train)) > train_args['overfitting_thres']:
            if acu_valid_max < torch.mean(torch.tensor(acu_valid)):
                torch.save(Classifier, train_args['save_dir'] + f'/Model/Community/{resolution}/ViT_L_AllenCommunity_{key}_{ind}.pth')
                torch.save(epoch, train_args['save_dir'] + f'/Model/Community/{resolution}/ViT_L_AllenCommunity_{key}_epoch{ind}.pt')
                acu_valid_max = torch.mean(torch.tensor(acu_valid))

        acu_array_valid.append(torch.mean(torch.tensor(acu_valid)))
        time_array_valid.append(time.time() - time0_valid)

    torch.save(torch.tensor(acu_array_train), train_args['save_dir'] + f'/Model/Community/{resolution}/ViT_L_AllenCommunity_{key}_train_acu{ind}.pt')
    torch.save(torch.tensor(acu_array_valid), train_args['save_dir'] + f'/Model/Community/{resolution}/ViT_L_AllenCommunity_{key}_valid_acu{ind}.pt')

    return

def net_train_RNN_L(train_iter, valid_iter, Classifier, spectro_args, train_args, key, ind, resolution, device):
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(Classifier.parameters(), train_args['lr'])
    # print('lr: ' + train_args['lr'])
    acu_array_train = []
    acu_array_valid = []
    time_array_train = []
    time_array_valid = []
    acu_valid_max = 0
    for epoch in range(0, train_args['epochs']):
        Classifier.train()
        acu_train = []
        time0_train = time.time()
        epoch0 = 0
        for x_train1, y_train, coordinate_train in train_iter:
            x_train = lfp_spectro(x_train1, spectro_args, train_args).squeeze(1).permute(0, 2, 1)
            y_train = y_train.to(device)
            py_train = Classifier(x_train.to(device))
            del x_train, x_train1
            if epoch0 % 800 == 0:
                print((torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu())
            L = loss_fn(py_train,y_train.to(device))
            optimizer.zero_grad()
            L.backward()
            optimizer.step()
            acu_train.append((torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu())
            epoch0 += 1
        print(f'Acu Train: {torch.mean(torch.tensor(acu_train))}')

        acu_array_train.append(torch.mean(torch.tensor(acu_train)))
        time_array_train.append(time.time() - time0_train)

        Classifier.eval()
        acu_valid = []
        time0_valid = time.time()
        for x_valid1, y_valid, coordinate_valid in valid_iter:
            x_valid = lfp_spectro(x_valid1, spectro_args, train_args).squeeze(1).permute(0, 2, 1)
            y_valid = y_valid.to(device)
            py_valid = Classifier(x_valid.to(device))
            del x_valid, x_valid1
            acu_valid.append((torch.sum(torch.argmax(py_valid, dim=1) == y_valid) / y_valid.size(0)).detach().cpu())

        print(f'Acu valid: {torch.mean(torch.tensor(acu_valid))}')
        if torch.mean(torch.tensor(acu_train)) > train_args['overfitting_thres']:
            if acu_valid_max < torch.mean(torch.tensor(acu_valid)):
                torch.save(Classifier, train_args['save_dir'] + f'/Model/Community/{resolution}/RNN_L_AllenCommunity_{key}_{ind}.pth')
                torch.save(epoch, train_args['save_dir'] + f'/Model/Community/{resolution}/RNN_L_AllenCommunity_{key}_epoch{ind}.pt')
                acu_valid_max = torch.mean(torch.tensor(acu_valid))


        acu_array_valid.append(torch.mean(torch.tensor(acu_valid)))
        time_array_valid.append(time.time() - time0_valid)

    torch.save(torch.tensor(acu_array_train), train_args['save_dir'] + f'/Model/Community/{resolution}/RNN_L_AllenCommunity_{key}_train_acu{ind}.pt')
    torch.save(torch.tensor(acu_array_valid), train_args['save_dir'] + f'/Model/Community/{resolution}/RNN_L_AllenCommunity_{key}_valid_acu{ind}.pt')

    return

# %%
save_dir = '/content/drive/MyDrive/Project/BrainRegionId/Nature/'

for resolution in [1.0, 1.2]:
    communities = community_dict[resolution]['communities']
    communities_label = community_dict[resolution]['communities_label']
    communities_acronym = community_dict[resolution]['communities_acronym']

    id_community_mapping = []
    for acronym in acronym_list:
        if acronym in communities_acronym:
            id_community_mapping.append(communities_label[np.argwhere(communities_acronym == acronym).flatten()])
        else:
            id_community_mapping.append(np.array([-1]))

    id_community_mapping = np.array(id_community_mapping)

    brain_region_index_intersect = id_community_mapping[brain_region_index].squeeze(-1)
    dropout_index = np.argwhere(brain_region_index_intersect == np.array([-1]))[:, 0]

    brain_region_index_intersect = torch.tensor(brain_region_index_intersect, dtype=torch.long)

    key = 'stimOff_times'
    model_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project44/Model/Allen'
    subject_od_ind = torch.load(model_dir + f'/subject_od_ind_Allen_{key}{0}.pt', weights_only=False)
    subject_od_list = torch.load(model_dir + f'/subject_od_list_Allen_{key}{0}.pt', weights_only=False)
    train_ind, valid_ind, test_ind, test_subject_ind = dat_ind_gen(list_dict, subject_od_ind, key)
    train_ind = np.setdiff1d(train_ind, dropout_index)
    valid_ind = np.setdiff1d(valid_ind, dropout_index)
    test_ind = np.setdiff1d(test_ind, dropout_index)
    train_iter_AnyNet, valid_iter_AnyNet, test_iter_AnyNet = iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index_intersect, coordinate_list)

    c0 = 64 * 4
    k0 = 1.0

    model_args = {
        'arch':((2,c0 * 2,1,k0), (2,c0 * 3,1,k0), (2,c0 * 4,1,k0), (2,c0 * 5,1,k0)),
        'stem_channels':c0,
    }
    train_args = {
        'overfitting_thres':0.60,
        'lr':5e-4,
        'norm':True,
        'temp':[True, True],
        'epochs':10,
        'save_dir':save_dir,
    }


    for ind in range(0, 1):
        Classifier = AnyNet_L(model_args['arch'], model_args['stem_channels'], frequency_bin=spectro_args['spectro_img'][0], num_classes=len(np.unique(communities_label))).to(device)
        Classifier.apply(init_cnn)
        net_train_AnyNet_L(train_iter_AnyNet, valid_iter_AnyNet, Classifier.to(device), spectro_args, train_args, key, ind, resolution, device)

    train_iter_ViT, valid_iter_ViT, test_iter_ViT = iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index_intersect, coordinate_list)

    train_args['epochs'] = 50
    for ind in range(0, 1):
        img_size, patch_size = (224, 28), (28, 28)
        num_hiddens, mlp_num_hiddens, num_heads, num_blks = 512, 2048, 8, 4
        emb_dropout, blk_dropout = 0.1, 0.1
        Classifier = ViT_L(spectro_args['spectro_img'][0], img_size, patch_size, num_hiddens, mlp_num_hiddens, num_heads, num_blks, emb_dropout, blk_dropout, num_classes=len(np.unique(communities_label))).to(device)
        net_train_ViT_L(train_iter_ViT, valid_iter_ViT, Classifier.to(device), spectro_args, train_args, key, ind, resolution, device)

    del train_iter_ViT, valid_iter_ViT, test_iter_ViT
    train_iter_RNN, valid_iter_RNN, test_iter_RNN = iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index_intersect, coordinate_list)
    train_args['epochs'] = 30

    RNN_args = {
    'input_size':224,
    'hidden_size':512 * 2,
    'num_layers':2,
    'category_num':len(np.unique(communities_label)),
    'data_len':28,
    }
    for ind in range(0, 1):
        Classifier = RNN_L(spectro_args['spectro_img'][0], RNN_args).to(device)
        net_train_RNN_L(train_iter_RNN, valid_iter_RNN, Classifier.to(device), spectro_args, train_args, key, ind, resolution, device)
# Out:
# accu_fun is correct>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# tensor(0.)
# tensor(0.3672)
# tensor(0.3750)
# tensor(0.3125)
# tensor(0.4375)
# tensor(0.5312)
# tensor(0.4922)
# tensor(0.4688)
# tensor(0.5469)
# tensor(0.5391)
# Acu Train: 0.46813657879829407
# Acu valid: 0.5135563611984253
# tensor(0.6250)
# tensor(0.6797)
# tensor(0.6094)
# tensor(0.6406)
# tensor(0.6484)
# tensor(0.6875)
# tensor(0.6641)
# tensor(0.6406)
# tensor(0.6641)
# tensor(0.6719)
# Acu Train: 0.6295590996742249
# Acu valid: 0.5514593124389648
# tensor(0.7734)
# tensor(0.6953)
# tensor(0.7188)
# tensor(0.6562)
# tensor(0.7188)
# tensor(0.7109)
# tensor(0.7734)
# tensor(0.6797)
# tensor(0.7656)
# tensor(0.7266)
# Acu Train: 0.7157343029975891
# Acu valid: 0.5756331086158752
# tensor(0.7578)
# tensor(0.6953)
# tensor(0.7344)
# tensor(0.7891)
# tensor(0.7891)
# tensor(0.7812)
# tensor(0.8438)
# tensor(0.7891)
# tensor(0.8203)
# tensor(0.8047)
# Acu Train: 0.7782541513442993
# Acu valid: 0.5641950964927673
# tensor(0.8281)
# tensor(0.8281)
# tensor(0.8125)
# tensor(0.8203)
# tensor(0.8047)
# tensor(0.8125)
# tensor(0.8516)
# tensor(0.8203)
# tensor(0.8750)
# tensor(0.8281)
# Acu Train: 0.8264105916023254
# Acu valid: 0.5575097799301147
# tensor(0.8750)
# tensor(0.9297)
# tensor(0.8516)
# tensor(0.8828)
# tensor(0.8672)
# tensor(0.8516)
# tensor(0.8438)
# tensor(0.8984)
# tensor(0.8828)
# tensor(0.8594)
# Acu Train: 0.8609617948532104
# Acu valid: 0.5512951612472534
# tensor(0.8906)
# tensor(0.8828)
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.8516)
# tensor(0.8281)
# tensor(0.9062)
# tensor(0.8828)
# tensor(0.8906)
# tensor(0.9219)
# Acu Train: 0.8863137364387512
# Acu valid: 0.5401421785354614
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.8828)
# tensor(0.8906)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.9297)
# Acu Train: 0.9056988954544067
# Acu valid: 0.5440678596496582
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.8906)
# tensor(0.9688)
# tensor(0.8906)
# tensor(0.9141)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.8984)
# tensor(0.8828)
# Acu Train: 0.9198576807975769
# Acu valid: 0.5461494326591492
# tensor(0.9531)
# tensor(0.9688)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.9531)
# tensor(0.9297)
# Acu Train: 0.9304622411727905
# Acu valid: 0.5524741411209106
# tensor(0.0312)
# tensor(0.3750)
# tensor(0.4062)
# tensor(0.3594)
# tensor(0.3984)
# tensor(0.3125)
# tensor(0.4531)
# tensor(0.3906)
# tensor(0.3672)
# tensor(0.4141)
# Acu Train: 0.3516910672187805
# Acu valid: 0.4199834167957306
# tensor(0.4141)
# tensor(0.4531)
# tensor(0.4297)
# tensor(0.3594)
# tensor(0.4844)
# tensor(0.4453)
# tensor(0.4375)
# tensor(0.4453)
# tensor(0.5234)
# tensor(0.4844)
# Acu Train: 0.4334042966365814
# Acu valid: 0.4651547074317932
# tensor(0.5234)
# tensor(0.4375)
# tensor(0.4141)
# tensor(0.4609)
# tensor(0.5312)
# tensor(0.4609)
# tensor(0.4688)
# tensor(0.4844)
# tensor(0.4844)
# tensor(0.5156)
# Acu Train: 0.4722244143486023
# Acu valid: 0.4924768805503845
# tensor(0.5000)
# tensor(0.3906)
# tensor(0.6016)
# tensor(0.4609)
# tensor(0.4766)
# tensor(0.6016)
# tensor(0.4766)
# tensor(0.5234)
# tensor(0.4766)
# tensor(0.5078)
# Acu Train: 0.4937584102153778
# Acu valid: 0.5011487603187561
# tensor(0.4688)
# tensor(0.4766)
# tensor(0.5156)
# tensor(0.4844)
# tensor(0.5078)
# tensor(0.5781)
# tensor(0.5391)
# tensor(0.4531)
# tensor(0.5078)
# tensor(0.5625)
# Acu Train: 0.5110220313072205
# Acu valid: 0.5248152017593384
# tensor(0.6406)
# tensor(0.5859)
# tensor(0.4766)
# tensor(0.5625)
# tensor(0.5859)
# tensor(0.4609)
# tensor(0.5469)
# tensor(0.6328)
# tensor(0.5938)
# tensor(0.5156)
# Acu Train: 0.5292150378227234
# Acu valid: 0.5287603139877319
# tensor(0.5625)
# tensor(0.5391)
# tensor(0.5312)
# tensor(0.5938)
# tensor(0.5078)
# tensor(0.5469)
# tensor(0.5000)
# tensor(0.5156)
# tensor(0.5078)
# tensor(0.5234)
# Acu Train: 0.5267000794410706
# Acu valid: 0.5333985686302185
# tensor(0.4531)
# tensor(0.5547)
# tensor(0.5469)
# tensor(0.5234)
# tensor(0.6016)
# tensor(0.5156)
# tensor(0.5781)
# tensor(0.5000)
# tensor(0.6875)
# tensor(0.5938)
# Acu Train: 0.5515395998954773
# Acu valid: 0.5504119992256165
# tensor(0.5234)
# tensor(0.6016)
# tensor(0.6016)
# tensor(0.5312)
# tensor(0.4531)
# tensor(0.5000)
# tensor(0.5391)
# tensor(0.5234)
# tensor(0.5625)
# tensor(0.5156)
# Acu Train: 0.5635519623756409
# Acu valid: 0.4831809103488922
# tensor(0.5625)
# tensor(0.6172)
# tensor(0.5625)
# tensor(0.5000)
# tensor(0.6016)
# tensor(0.6328)
# tensor(0.6406)
# tensor(0.5391)
# tensor(0.5625)
# tensor(0.5547)
# Acu Train: 0.5785949230194092
# Acu valid: 0.5643613338470459
# tensor(0.5781)
# tensor(0.5469)
# tensor(0.5625)
# tensor(0.5469)
# tensor(0.5859)
# tensor(0.5312)
# tensor(0.5703)
# tensor(0.5547)
# tensor(0.6328)
# tensor(0.5938)
# Acu Train: 0.5924265384674072
# Acu valid: 0.5608092546463013
# tensor(0.5547)
# tensor(0.5859)
# tensor(0.6484)
# tensor(0.6094)
# tensor(0.6328)
# tensor(0.6016)
# tensor(0.6406)
# tensor(0.6016)
# tensor(0.5469)
# tensor(0.5000)
# Acu Train: 0.6049227714538574
# Acu valid: 0.5727288126945496
# tensor(0.6250)
# tensor(0.6328)
# tensor(0.5859)
# tensor(0.5625)
# tensor(0.5703)
# tensor(0.6250)
# tensor(0.6094)
# tensor(0.6875)
# tensor(0.5859)
# tensor(0.6016)
# Acu Train: 0.6140947341918945
# Acu valid: 0.5816965103149414
# tensor(0.5703)
# tensor(0.5547)
# tensor(0.6641)
# tensor(0.6875)
# tensor(0.5547)
# tensor(0.6875)
# tensor(0.5703)
# tensor(0.6172)
# tensor(0.6328)
# tensor(0.6406)
# Acu Train: 0.623601496219635
# Acu valid: 0.5831001400947571
# tensor(0.6562)
# tensor(0.6250)
# tensor(0.6328)
# tensor(0.4688)
# tensor(0.6094)
# tensor(0.6172)
# tensor(0.6250)
# tensor(0.6094)
# tensor(0.5703)
# tensor(0.5938)
# Acu Train: 0.6271921396255493
# Acu valid: 0.5870581865310669
# tensor(0.6484)
# tensor(0.5625)
# tensor(0.6250)
# tensor(0.5703)
# tensor(0.6562)
# tensor(0.5938)
# tensor(0.6328)
# tensor(0.6484)
# tensor(0.6328)
# tensor(0.6641)
# Acu Train: 0.642065167427063
# Acu valid: 0.5868833065032959
# tensor(0.6953)
# tensor(0.7109)
# tensor(0.6094)
# tensor(0.6328)
# tensor(0.6016)
# tensor(0.6641)
# tensor(0.6641)
# tensor(0.6328)
# tensor(0.6641)
# tensor(0.6484)
# Acu Train: 0.6509636640548706
# Acu valid: 0.5872611403465271
# tensor(0.5938)
# tensor(0.6641)
# tensor(0.6328)
# tensor(0.6016)
# tensor(0.6094)
# tensor(0.7188)
# tensor(0.5703)
# tensor(0.5781)
# tensor(0.6797)
# tensor(0.7422)
# Acu Train: 0.6499785780906677
# Acu valid: 0.5875785946846008
# tensor(0.6406)
# tensor(0.7344)
# tensor(0.6562)
# tensor(0.6875)
# tensor(0.6719)
# tensor(0.6797)
# tensor(0.6953)
# tensor(0.5938)
# tensor(0.6328)
# tensor(0.5625)
# Acu Train: 0.6548040509223938
# Acu valid: 0.5951277017593384
# tensor(0.6094)
# tensor(0.6328)
# tensor(0.7266)
# tensor(0.6172)
# tensor(0.6562)
# tensor(0.6562)
# tensor(0.6797)
# tensor(0.7578)
# tensor(0.7344)
# tensor(0.6641)
# Acu Train: 0.6602281928062439
# Acu valid: 0.5919512510299683
# tensor(0.6797)
# tensor(0.7031)
# tensor(0.6172)
# tensor(0.6484)
# tensor(0.7109)
# tensor(0.6172)
# tensor(0.6406)
# tensor(0.7031)
# tensor(0.6797)
# tensor(0.6250)
# Acu Train: 0.6615732908248901
# Acu valid: 0.5952507853507996
# tensor(0.6406)
# tensor(0.6562)
# tensor(0.6797)
# tensor(0.6016)
# tensor(0.7344)
# tensor(0.6797)
# tensor(0.6328)
# tensor(0.7031)
# tensor(0.6406)
# tensor(0.6875)
# Acu Train: 0.6620833873748779
# Acu valid: 0.5854819416999817
# tensor(0.5703)
# tensor(0.6719)
# tensor(0.6641)
# tensor(0.6562)
# tensor(0.7891)
# tensor(0.6719)
# tensor(0.6562)
# tensor(0.6094)
# tensor(0.7031)
# tensor(0.7266)
# Acu Train: 0.6798924207687378
# Acu valid: 0.5935859084129333
# tensor(0.6875)
# tensor(0.6484)
# tensor(0.6641)
# tensor(0.6328)
# tensor(0.6719)
# tensor(0.6953)
# tensor(0.6250)
# tensor(0.6797)
# tensor(0.6797)
# tensor(0.6328)
# Acu Train: 0.675912082195282
# Acu valid: 0.5939270257949829
# tensor(0.7891)
# tensor(0.7422)
# tensor(0.7109)
# tensor(0.6797)
# tensor(0.6562)
# tensor(0.6641)
# tensor(0.6406)
# tensor(0.7031)
# tensor(0.5859)
# tensor(0.6875)
# Acu Train: 0.6833762526512146
# Acu valid: 0.5985416173934937
# tensor(0.7031)
# tensor(0.6797)
# tensor(0.6953)
# tensor(0.7344)
# tensor(0.6172)
# tensor(0.6719)
# tensor(0.6094)
# tensor(0.7422)
# tensor(0.6641)
# tensor(0.6953)
# Acu Train: 0.6829810738563538
# Acu valid: 0.5556138753890991
# tensor(0.6641)
# tensor(0.7266)
# tensor(0.6641)
# tensor(0.6562)
# tensor(0.7422)
# tensor(0.7109)
# tensor(0.7656)
# tensor(0.7422)
# tensor(0.6953)
# tensor(0.7656)
# Acu Train: 0.694291353225708
# Acu valid: 0.5956955552101135
# tensor(0.6641)
# tensor(0.6484)
# tensor(0.7344)
# tensor(0.7188)
# tensor(0.6641)
# tensor(0.6797)
# tensor(0.7188)
# tensor(0.6094)
# tensor(0.7188)
# tensor(0.7500)
# Acu Train: 0.7052087783813477
# Acu valid: 0.5904721021652222
# tensor(0.6250)
# tensor(0.7266)
# tensor(0.6875)
# tensor(0.7734)
# tensor(0.7578)
# tensor(0.7266)
# tensor(0.7422)
# tensor(0.7344)
# tensor(0.6875)
# tensor(0.6953)
# Acu Train: 0.711906373500824
# Acu valid: 0.5852875709533691
# tensor(0.6719)
# tensor(0.6875)
# tensor(0.7891)
# tensor(0.7578)
# tensor(0.7422)
# tensor(0.7734)
# tensor(0.6797)
# tensor(0.7188)
# tensor(0.6875)
# tensor(0.7344)
# Acu Train: 0.7169339656829834
# Acu valid: 0.5935081839561462
# tensor(0.6875)
# tensor(0.7188)
# tensor(0.7578)
# tensor(0.7188)
# tensor(0.6172)
# tensor(0.7422)
# tensor(0.7109)
# tensor(0.6641)
# tensor(0.6953)
# tensor(0.7422)
# Acu Train: 0.7169966697692871
# Acu valid: 0.5894853472709656
# tensor(0.6719)
# tensor(0.7266)
# tensor(0.7109)
# tensor(0.6562)
# tensor(0.7500)
# tensor(0.7188)
# tensor(0.6953)
# tensor(0.7109)
# tensor(0.6953)
# tensor(0.7969)
# Acu Train: 0.7262322902679443
# Acu valid: 0.5944604277610779
# tensor(0.7578)
# tensor(0.7109)
# tensor(0.7500)
# tensor(0.7422)
# tensor(0.7812)
# tensor(0.7344)
# tensor(0.6875)
# tensor(0.7578)
# tensor(0.7031)
# tensor(0.7812)
# Acu Train: 0.7313864827156067
# Acu valid: 0.5973798036575317
# tensor(0.8125)
# tensor(0.7188)
# tensor(0.7578)
# tensor(0.7812)
# tensor(0.7422)
# tensor(0.7500)
# tensor(0.8047)
# tensor(0.7422)
# tensor(0.7344)
# tensor(0.6484)
# Acu Train: 0.7342820763587952
# Acu valid: 0.586017370223999
# tensor(0.7500)
# tensor(0.7422)
# tensor(0.6719)
# tensor(0.7578)
# tensor(0.7500)
# tensor(0.6250)
# tensor(0.7578)
# tensor(0.7188)
# tensor(0.7344)
# tensor(0.6484)
# Acu Train: 0.738988995552063
# Acu valid: 0.5966348648071289
# tensor(0.8281)
# tensor(0.7578)
# tensor(0.7734)
# tensor(0.7344)
# tensor(0.7734)
# tensor(0.6953)
# tensor(0.7344)
# tensor(0.7266)
# tensor(0.7734)
# tensor(0.7578)
# Acu Train: 0.7190168499946594
# Acu valid: 0.5955120325088501
# tensor(0.7188)
# tensor(0.7344)
# tensor(0.7500)
# tensor(0.7734)
# tensor(0.7422)
# tensor(0.7578)
# tensor(0.7656)
# tensor(0.6953)
# tensor(0.7656)
# tensor(0.7891)
# Acu Train: 0.737594723701477
# Acu valid: 0.5947540998458862
# tensor(0.7812)
# tensor(0.7656)
# tensor(0.7422)
# tensor(0.7266)
# tensor(0.7656)
# tensor(0.7969)
# tensor(0.8203)
# tensor(0.7500)
# tensor(0.6875)
# tensor(0.7266)
# Acu Train: 0.7445127964019775
# Acu valid: 0.5979931354522705
# tensor(0.7812)
# tensor(0.7344)
# tensor(0.7422)
# tensor(0.8125)
# tensor(0.7109)
# tensor(0.7188)
# tensor(0.7891)
# tensor(0.7422)
# tensor(0.8516)
# tensor(0.7891)
# Acu Train: 0.752996027469635
# Acu valid: 0.5918260216712952
# tensor(0.7344)
# tensor(0.8125)
# tensor(0.7266)
# tensor(0.7891)
# tensor(0.7734)
# tensor(0.7812)
# tensor(0.7422)
# tensor(0.7578)
# tensor(0.7031)
# tensor(0.7500)
# Acu Train: 0.7574424743652344
# Acu valid: 0.5933203101158142
# tensor(0.8281)
# tensor(0.7812)
# tensor(0.6797)
# tensor(0.7734)
# tensor(0.8672)
# tensor(0.7266)
# tensor(0.7188)
# tensor(0.7656)
# tensor(0.7578)
# tensor(0.7656)
# Acu Train: 0.7629071474075317
# Acu valid: 0.5953350067138672
# tensor(0.7891)
# tensor(0.7734)
# tensor(0.7031)
# tensor(0.7266)
# tensor(0.7891)
# tensor(0.7500)
# tensor(0.7891)
# tensor(0.6953)
# tensor(0.7734)
# tensor(0.7812)
# Acu Train: 0.768638014793396
# Acu valid: 0.5942897796630859
# tensor(0.7500)
# tensor(0.8438)
# tensor(0.7422)
# tensor(0.7344)
# tensor(0.8516)
# tensor(0.7188)
# tensor(0.7344)
# tensor(0.7812)
# tensor(0.8125)
# tensor(0.7188)
# Acu Train: 0.7619456052780151
# Acu valid: 0.5985955595970154
# tensor(0.8125)
# tensor(0.8047)
# tensor(0.7969)
# tensor(0.7578)
# tensor(0.8438)
# tensor(0.7500)
# tensor(0.8047)
# tensor(0.7812)
# tensor(0.7578)
# tensor(0.7969)
# Acu Train: 0.7703732848167419
# Acu valid: 0.5943589210510254
# tensor(0.7891)
# tensor(0.7812)
# tensor(0.7812)
# tensor(0.7812)
# tensor(0.8047)
# tensor(0.8125)
# tensor(0.7578)
# tensor(0.7812)
# tensor(0.7969)
# tensor(0.8203)
# Acu Train: 0.7760197520256042
# Acu valid: 0.5955120325088501
# tensor(0.7500)
# tensor(0.7422)
# tensor(0.7969)
# tensor(0.8125)
# tensor(0.7422)
# tensor(0.7891)
# tensor(0.7422)
# tensor(0.7812)
# tensor(0.7500)
# tensor(0.7344)
# Acu Train: 0.7783253192901611
# Acu valid: 0.5958273410797119
# tensor(0.7969)
# tensor(0.8047)
# tensor(0.7734)
# tensor(0.8047)
# tensor(0.7656)
# tensor(0.7422)
# tensor(0.7734)
# tensor(0.7891)
# tensor(0.8203)
# tensor(0.7422)
# Acu Train: 0.7838220000267029
# Acu valid: 0.5933699011802673
# tensor(0.7969)
# tensor(0.7578)
# tensor(0.7734)
# tensor(0.7578)
# tensor(0.7656)
# tensor(0.7734)
# tensor(0.7812)
# tensor(0.8438)
# tensor(0.7422)
# tensor(0.7422)
# Acu Train: 0.7809892296791077
# Acu valid: 0.5925083160400391
# tensor(0.7812)
# tensor(0.7422)
# tensor(0.7969)
# tensor(0.8359)
# tensor(0.7891)
# tensor(0.8125)
# tensor(0.7344)
# tensor(0.8125)
# tensor(0.8047)
# tensor(0.8047)
# Acu Train: 0.7819497585296631
# Acu valid: 0.5944863557815552
# tensor(0.8594)
# tensor(0.7656)
# tensor(0.7969)
# tensor(0.7578)
# tensor(0.7734)
# tensor(0.7734)
# tensor(0.6484)
# tensor(0.8125)
# tensor(0.8125)
# tensor(0.7969)
# Acu Train: 0.7633588910102844
# Acu valid: 0.5955919027328491
# tensor(0.0156)
# tensor(0.3281)
# tensor(0.3359)
# tensor(0.4219)
# tensor(0.5156)
# tensor(0.4609)
# tensor(0.5469)
# tensor(0.4844)
# tensor(0.5312)
# tensor(0.5625)
# Acu Train: 0.4296818971633911
# Acu valid: 0.4858217239379883
# tensor(0.6250)
# tensor(0.5469)
# tensor(0.5547)
# tensor(0.5859)
# tensor(0.6406)
# tensor(0.5781)
# tensor(0.6406)
# tensor(0.5469)
# tensor(0.6172)
# tensor(0.6016)
# Acu Train: 0.5935376286506653
# Acu valid: 0.5183695554733276
# tensor(0.6875)
# tensor(0.6562)
# tensor(0.7031)
# tensor(0.6797)
# tensor(0.6406)
# tensor(0.6797)
# tensor(0.6719)
# tensor(0.7422)
# tensor(0.6641)
# tensor(0.7031)
# Acu Train: 0.6785361766815186
# Acu valid: 0.5287127494812012
# tensor(0.7109)
# tensor(0.7031)
# tensor(0.6562)
# tensor(0.7812)
# tensor(0.7500)
# tensor(0.7188)
# tensor(0.7109)
# tensor(0.7031)
# tensor(0.7266)
# tensor(0.7812)
# Acu Train: 0.7362737655639648
# Acu valid: 0.5258603096008301
# tensor(0.7969)
# tensor(0.7031)
# tensor(0.7812)
# tensor(0.7734)
# tensor(0.8125)
# tensor(0.7109)
# tensor(0.7578)
# tensor(0.7656)
# tensor(0.8125)
# tensor(0.7500)
# Acu Train: 0.7796728014945984
# Acu valid: 0.5306777954101562
# tensor(0.8281)
# tensor(0.8203)
# tensor(0.7969)
# tensor(0.8281)
# tensor(0.7969)
# tensor(0.8125)
# tensor(0.7812)
# tensor(0.8281)
# tensor(0.8594)
# tensor(0.8047)
# Acu Train: 0.8135715126991272
# Acu valid: 0.5271667242050171
# tensor(0.8516)
# tensor(0.8594)
# tensor(0.7891)
# tensor(0.8203)
# tensor(0.8281)
# tensor(0.8359)
# tensor(0.7812)
# tensor(0.8594)
# tensor(0.7969)
# tensor(0.8047)
# Acu Train: 0.8383044600486755
# Acu valid: 0.5260869860649109
# tensor(0.8438)
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.8672)
# tensor(0.8516)
# tensor(0.8047)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.8750)
# Acu Train: 0.8575748801231384
# Acu valid: 0.5232280492782593
# tensor(0.8828)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.8516)
# tensor(0.9062)
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.8438)
# tensor(0.8984)
# Acu Train: 0.8733503222465515
# Acu valid: 0.5223556756973267
# tensor(0.9219)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.9141)
# tensor(0.8906)
# tensor(0.8359)
# tensor(0.8906)
# tensor(0.8516)
# tensor(0.8281)
# tensor(0.8594)
# Acu Train: 0.885125994682312
# Acu valid: 0.5191555023193359
# tensor(0.9141)
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.8594)
# tensor(0.8672)
# tensor(0.8828)
# tensor(0.8984)
# tensor(0.8516)
# tensor(0.9062)
# tensor(0.9375)
# Acu Train: 0.8948177695274353
# Acu valid: 0.515199601650238
# tensor(0.8594)
# tensor(0.9297)
# tensor(0.8906)
# tensor(0.9141)
# tensor(0.8750)
# tensor(0.8750)
# tensor(0.8672)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.8750)
# Acu Train: 0.9021211266517639
# Acu valid: 0.5099610686302185
# tensor(0.9609)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.9219)
# tensor(0.9609)
# tensor(0.9297)
# tensor(0.8750)
# tensor(0.8984)
# tensor(0.8984)
# tensor(0.9062)
# Acu Train: 0.9074240922927856
# Acu valid: 0.5189438462257385
# tensor(0.9062)
# tensor(0.9375)
# tensor(0.9688)
# tensor(0.8906)
# tensor(0.9297)
# tensor(0.8984)
# tensor(0.8438)
# tensor(0.9688)
# tensor(0.8906)
# tensor(0.9453)
# Acu Train: 0.9118766784667969
# Acu valid: 0.5158279538154602
# tensor(0.9531)
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.9453)
# tensor(0.8594)
# tensor(0.9531)
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.8984)
# tensor(0.9062)
# Acu Train: 0.916329562664032
# Acu valid: 0.5208808183670044
# tensor(0.9297)
# tensor(0.9062)
# tensor(0.9375)
# tensor(0.8984)
# tensor(0.8984)
# tensor(0.9375)
# tensor(0.9531)
# tensor(0.9297)
# tensor(0.8984)
# tensor(0.9141)
# Acu Train: 0.918639063835144
# Acu valid: 0.5204554796218872
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.8984)
# tensor(0.9531)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.8828)
# tensor(0.8984)
# tensor(0.9297)
# tensor(0.8672)
# Acu Train: 0.9216752052307129
# Acu valid: 0.5068840384483337
# tensor(0.9297)
# tensor(0.9297)
# tensor(0.9375)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.8984)
# tensor(0.9141)
# Acu Train: 0.9229083061218262
# Acu valid: 0.5141005516052246
# tensor(0.9453)
# tensor(0.9062)
# tensor(0.9531)
# tensor(0.9766)
# tensor(0.9375)
# tensor(0.9844)
# tensor(0.8984)
# tensor(0.9688)
# tensor(0.9453)
# tensor(0.8984)
# Acu Train: 0.9255332946777344
# Acu valid: 0.5115546584129333
# tensor(0.9219)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9062)
# Acu Train: 0.9254704117774963
# Acu valid: 0.5165557265281677
# tensor(0.9453)
# tensor(0.9609)
# tensor(0.9766)
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.8906)
# Acu Train: 0.9270099401473999
# Acu valid: 0.5167111754417419
# tensor(0.9609)
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.9062)
# tensor(0.9297)
# tensor(0.9062)
# tensor(0.9531)
# tensor(0.9219)
# tensor(0.9141)
# Acu Train: 0.9274331331253052
# Acu valid: 0.5168514847755432
# tensor(0.9609)
# tensor(0.9609)
# tensor(0.8984)
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.9062)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.9297)
# Acu Train: 0.9260904788970947
# Acu valid: 0.5129711627960205
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.8984)
# tensor(0.8984)
# tensor(0.8984)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.9453)
# tensor(0.9609)
# tensor(0.9141)
# Acu Train: 0.9282912015914917
# Acu valid: 0.5137636661529541
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.9297)
# tensor(0.9297)
# Acu Train: 0.9269331693649292
# Acu valid: 0.5136124491691589
# tensor(0.9609)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.9531)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.8906)
# tensor(0.9219)
# tensor(0.8672)
# tensor(0.9453)
# Acu Train: 0.9268529415130615
# Acu valid: 0.5143380165100098
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9297)
# tensor(0.8984)
# tensor(0.8906)
# tensor(0.9219)
# tensor(0.8984)
# tensor(0.9453)
# tensor(0.9531)
# tensor(0.9453)
# Acu Train: 0.9261025190353394
# Acu valid: 0.5035542845726013
# tensor(0.9375)
# tensor(0.9531)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.9531)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.8672)
# tensor(0.8828)
# tensor(0.9141)
# Acu Train: 0.9239402413368225
# Acu valid: 0.5086762309074402
# tensor(0.9297)
# tensor(0.9453)
# tensor(0.8750)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.9375)
# tensor(0.9141)
# Acu Train: 0.9216838479042053
# Acu valid: 0.5099157094955444
# tensor(0.9297)
# tensor(0.9453)
# tensor(0.8906)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.8906)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.9375)
# Acu Train: 0.9214111566543579
# Acu valid: 0.5128437876701355
# accu_fun is correct>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# tensor(0.0078)
# tensor(0.3516)
# tensor(0.4688)
# tensor(0.3750)
# tensor(0.3438)
# tensor(0.4375)
# tensor(0.5469)
# tensor(0.5625)
# tensor(0.5391)
# Acu Train: 0.4663987159729004
# Acu valid: 0.5155978202819824
# tensor(0.5781)
# tensor(0.6328)
# tensor(0.7109)
# tensor(0.6875)
# tensor(0.6719)
# tensor(0.6953)
# tensor(0.6797)
# tensor(0.6875)
# tensor(0.6797)
# Acu Train: 0.6392038464546204
# Acu valid: 0.5605406165122986
# tensor(0.6797)
# tensor(0.6406)
# tensor(0.7812)
# tensor(0.7656)
# tensor(0.7812)
# tensor(0.7578)
# tensor(0.7344)
# tensor(0.7656)
# tensor(0.7266)
# Acu Train: 0.7233242392539978
# Acu valid: 0.32474055886268616
# tensor(0.7969)
# tensor(0.7422)
# tensor(0.8203)
# tensor(0.7969)
# tensor(0.8047)
# tensor(0.8281)
# tensor(0.7578)
# tensor(0.7422)
# tensor(0.7734)
# Acu Train: 0.7853960990905762
# Acu valid: 0.5673155188560486
# tensor(0.8516)
# tensor(0.7500)
# tensor(0.8047)
# tensor(0.8672)
# tensor(0.8516)
# tensor(0.7656)
# tensor(0.8438)
# tensor(0.8594)
# tensor(0.8984)
# Acu Train: 0.8313922882080078
# Acu valid: 0.5621196031570435
# tensor(0.8516)
# tensor(0.8828)
# tensor(0.8438)
# tensor(0.8203)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.9141)
# tensor(0.8438)
# tensor(0.8516)
# Acu Train: 0.8664312362670898
# Acu valid: 0.5500038266181946
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.9141)
# tensor(0.8672)
# tensor(0.9219)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.8594)
# tensor(0.8359)
# Acu Train: 0.891690731048584
# Acu valid: 0.5505110025405884
# tensor(0.9375)
# tensor(0.9531)
# tensor(0.9062)
# tensor(0.9297)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.8750)
# tensor(0.9062)
# Acu Train: 0.910215437412262
# Acu valid: 0.5526193976402283
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.9688)
# tensor(0.8906)
# tensor(0.9297)
# tensor(0.9375)
# tensor(0.9453)
# tensor(0.9062)
# tensor(0.9062)
# Acu Train: 0.9234976172447205
# Acu valid: 0.5448310375213623
# tensor(0.9688)
# tensor(0.9609)
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.9766)
# tensor(0.9688)
# tensor(0.9609)
# Acu Train: 0.9338493943214417
# Acu valid: 0.5477887988090515
# tensor(0.)
# tensor(0.3203)
# tensor(0.3125)
# tensor(0.3125)
# tensor(0.3203)
# tensor(0.2578)
# tensor(0.3516)
# tensor(0.3906)
# tensor(0.4141)
# Acu Train: 0.32722207903862
# Acu valid: 0.37880411744117737
# tensor(0.3906)
# tensor(0.4141)
# tensor(0.3359)
# tensor(0.4531)
# tensor(0.4766)
# tensor(0.4141)
# tensor(0.5078)
# tensor(0.4453)
# tensor(0.4375)
# Acu Train: 0.41509631276130676
# Acu valid: 0.44191598892211914
# tensor(0.4062)
# tensor(0.4141)
# tensor(0.4766)
# tensor(0.4453)
# tensor(0.4297)
# tensor(0.4531)
# tensor(0.4375)
# tensor(0.4688)
# tensor(0.4922)
# Acu Train: 0.4647136330604553
# Acu valid: 0.30582571029663086
# tensor(0.2891)
# tensor(0.4531)
# tensor(0.4531)
# tensor(0.4609)
# tensor(0.5000)
# tensor(0.5234)
# tensor(0.4375)
# tensor(0.5234)
# tensor(0.5312)
# Acu Train: 0.48742905259132385
# Acu valid: 0.5020660758018494
# tensor(0.5625)
# tensor(0.5703)
# tensor(0.5469)
# tensor(0.4219)
# tensor(0.4453)
# tensor(0.5078)
# tensor(0.5234)
# tensor(0.5000)
# tensor(0.5000)
# Acu Train: 0.511412501335144
# Acu valid: 0.5029597282409668
# tensor(0.4922)
# tensor(0.5078)
# tensor(0.4688)
# tensor(0.5469)
# tensor(0.3594)
# tensor(0.4922)
# tensor(0.5000)
# tensor(0.5312)
# tensor(0.5703)
# Acu Train: 0.5184115171432495
# Acu valid: 0.518101692199707
# tensor(0.5938)
# tensor(0.5234)
# tensor(0.5469)
# tensor(0.5938)
# tensor(0.5469)
# tensor(0.5078)
# tensor(0.3828)
# tensor(0.4141)
# tensor(0.5078)
# Acu Train: 0.5124439597129822
# Acu valid: 0.5109201669692993
# tensor(0.4688)
# tensor(0.4375)
# tensor(0.4922)
# tensor(0.5469)
# tensor(0.5234)
# tensor(0.4688)
# tensor(0.5391)
# tensor(0.5156)
# tensor(0.5234)
# Acu Train: 0.5008594393730164
# Acu valid: 0.503765881061554
# tensor(0.4922)
# tensor(0.5156)
# tensor(0.5391)
# tensor(0.4844)
# tensor(0.5547)
# tensor(0.5938)
# tensor(0.6016)
# tensor(0.6797)
# tensor(0.5938)
# Acu Train: 0.5312004089355469
# Acu valid: 0.5352302193641663
# tensor(0.5469)
# tensor(0.5156)
# tensor(0.5234)
# tensor(0.6250)
# tensor(0.5391)
# tensor(0.5312)
# tensor(0.6094)
# tensor(0.5391)
# tensor(0.5625)
# Acu Train: 0.5577012896537781
# Acu valid: 0.5359225869178772
# tensor(0.5938)
# tensor(0.5234)
# tensor(0.6016)
# tensor(0.6016)
# tensor(0.5859)
# tensor(0.5859)
# tensor(0.5625)
# tensor(0.4375)
# tensor(0.6250)
# Acu Train: 0.5436278581619263
# Acu valid: 0.5373325347900391
# tensor(0.4766)
# tensor(0.5312)
# tensor(0.5234)
# tensor(0.6172)
# tensor(0.5547)
# tensor(0.5938)
# tensor(0.5547)
# tensor(0.5234)
# tensor(0.4531)
# Acu Train: 0.5506917834281921
# Acu valid: 0.5499544739723206
# tensor(0.6094)
# tensor(0.6719)
# tensor(0.5547)
# tensor(0.5547)
# tensor(0.5234)
# tensor(0.4844)
# tensor(0.5781)
# tensor(0.5703)
# tensor(0.6094)
# Acu Train: 0.571451723575592
# Acu valid: 0.5581867098808289
# tensor(0.5859)
# tensor(0.6562)
# tensor(0.6406)
# tensor(0.6328)
# tensor(0.5000)
# tensor(0.5391)
# tensor(0.6016)
# tensor(0.5938)
# tensor(0.4844)
# Acu Train: 0.5874570608139038
# Acu valid: 0.5625895857810974
# tensor(0.6328)
# tensor(0.6484)
# tensor(0.5703)
# tensor(0.5781)
# tensor(0.5078)
# tensor(0.6562)
# tensor(0.5781)
# tensor(0.6484)
# tensor(0.6016)
# Acu Train: 0.5998374819755554
# Acu valid: 0.5666854977607727
# tensor(0.5938)
# tensor(0.6562)
# tensor(0.6875)
# tensor(0.5938)
# tensor(0.6094)
# tensor(0.6641)
# tensor(0.6562)
# tensor(0.6016)
# tensor(0.5625)
# Acu Train: 0.6089053153991699
# Acu valid: 0.498468279838562
# tensor(0.5000)
# tensor(0.5938)
# tensor(0.6641)
# tensor(0.6016)
# tensor(0.6406)
# tensor(0.6328)
# tensor(0.6406)
# tensor(0.6641)
# tensor(0.6016)
# Acu Train: 0.6183833479881287
# Acu valid: 0.553001880645752
# tensor(0.5625)
# tensor(0.5938)
# tensor(0.6016)
# tensor(0.5703)
# tensor(0.6562)
# tensor(0.6250)
# tensor(0.6484)
# tensor(0.6875)
# tensor(0.6172)
# Acu Train: 0.6149855256080627
# Acu valid: 0.5757147669792175
# tensor(0.6094)
# tensor(0.6484)
# tensor(0.6875)
# tensor(0.6016)
# tensor(0.6016)
# tensor(0.6172)
# tensor(0.6094)
# tensor(0.7031)
# tensor(0.6875)
# Acu Train: 0.6269940137863159
# Acu valid: 0.5799807906150818
# tensor(0.5781)
# tensor(0.5703)
# tensor(0.6797)
# tensor(0.5703)
# tensor(0.6562)
# tensor(0.6328)
# tensor(0.6250)
# tensor(0.6562)
# tensor(0.6719)
# Acu Train: 0.6424294710159302
# Acu valid: 0.5721028447151184
# tensor(0.6172)
# tensor(0.6562)
# tensor(0.6094)
# tensor(0.5156)
# tensor(0.6797)
# tensor(0.6016)
# tensor(0.6797)
# tensor(0.6953)
# tensor(0.6406)
# Acu Train: 0.6190754175186157
# Acu valid: 0.578710675239563
# tensor(0.6797)
# tensor(0.6406)
# tensor(0.6250)
# tensor(0.5391)
# tensor(0.6797)
# tensor(0.5938)
# tensor(0.5781)
# tensor(0.6016)
# tensor(0.5625)
# Acu Train: 0.641166090965271
# Acu valid: 0.5777032971382141
# tensor(0.6406)
# tensor(0.6406)
# tensor(0.6016)
# tensor(0.6875)
# tensor(0.5469)
# tensor(0.6250)
# tensor(0.6797)
# tensor(0.5391)
# tensor(0.6094)
# Acu Train: 0.6341461539268494
# Acu valid: 0.5741719603538513
# tensor(0.6875)
# tensor(0.6406)
# tensor(0.6719)
# tensor(0.6328)
# tensor(0.6953)
# tensor(0.7031)
# tensor(0.6797)
# tensor(0.5859)
# tensor(0.6016)
# Acu Train: 0.6601276993751526
# Acu valid: 0.5820005536079407
# tensor(0.6406)
# tensor(0.6406)
# tensor(0.5156)
# tensor(0.5938)
# tensor(0.5938)
# tensor(0.5000)
# tensor(0.6797)
# tensor(0.7109)
# tensor(0.7031)
# Acu Train: 0.6587339639663696
# Acu valid: 0.5736737847328186
# tensor(0.6406)
# tensor(0.6953)
# tensor(0.6719)
# tensor(0.6953)
# tensor(0.7422)
# tensor(0.7031)
# tensor(0.6719)
# tensor(0.6641)
# tensor(0.7344)
# Acu Train: 0.6689138412475586
# Acu valid: 0.59211665391922
# tensor(0.6484)
# tensor(0.6953)
# tensor(0.7109)
# tensor(0.6797)
# tensor(0.7422)
# tensor(0.6406)
# tensor(0.7109)
# tensor(0.6719)
# tensor(0.7188)
# Acu Train: 0.6855462789535522
# Acu valid: 0.582627534866333
# tensor(0.6641)
# tensor(0.7500)
# tensor(0.6562)
# tensor(0.7500)
# tensor(0.7188)
# tensor(0.7422)
# tensor(0.6953)
# tensor(0.7188)
# tensor(0.7344)
# Acu Train: 0.6883611679077148
# Acu valid: 0.5949767827987671
# tensor(0.7109)
# tensor(0.7656)
# tensor(0.7109)
# tensor(0.7422)
# tensor(0.6797)
# tensor(0.6875)
# tensor(0.7109)
# tensor(0.7109)
# tensor(0.7500)
# Acu Train: 0.70196133852005
# Acu valid: 0.5866590738296509
# tensor(0.6562)
# tensor(0.6406)
# tensor(0.6406)
# tensor(0.7812)
# tensor(0.7500)
# tensor(0.6797)
# tensor(0.7344)
# tensor(0.7266)
# tensor(0.7344)
# Acu Train: 0.7037580609321594
# Acu valid: 0.5780786871910095
# tensor(0.6172)
# tensor(0.6875)
# tensor(0.6953)
# tensor(0.6875)
# tensor(0.7266)
# tensor(0.7500)
# tensor(0.6719)
# tensor(0.6719)
# tensor(0.8203)
# Acu Train: 0.7068141102790833
# Acu valid: 0.5961763858795166
# tensor(0.6875)
# tensor(0.6094)
# tensor(0.6719)
# tensor(0.7422)
# tensor(0.6484)
# tensor(0.7734)
# tensor(0.6250)
# tensor(0.7266)
# tensor(0.7031)
# Acu Train: 0.7063585519790649
# Acu valid: 0.5873473882675171
# tensor(0.7031)
# tensor(0.6641)
# tensor(0.7500)
# tensor(0.6797)
# tensor(0.6953)
# tensor(0.6953)
# tensor(0.6250)
# tensor(0.7031)
# tensor(0.6328)
# Acu Train: 0.6875668168067932
# Acu valid: 0.5633071064949036
# tensor(0.6016)
# tensor(0.6406)
# tensor(0.6875)
# tensor(0.6484)
# tensor(0.7422)
# tensor(0.7109)
# tensor(0.6562)
# tensor(0.6953)
# tensor(0.6406)
# Acu Train: 0.6840358972549438
# Acu valid: 0.5878174304962158
# tensor(0.7422)
# tensor(0.7422)
# tensor(0.7188)
# tensor(0.8047)
# tensor(0.7500)
# tensor(0.6797)
# tensor(0.7109)
# tensor(0.6562)
# tensor(0.7578)
# Acu Train: 0.700212836265564
# Acu valid: 0.5905477404594421
# tensor(0.7266)
# tensor(0.6953)
# tensor(0.7422)
# tensor(0.5859)
# tensor(0.7344)
# tensor(0.7500)
# tensor(0.6406)
# tensor(0.7031)
# tensor(0.6719)
# Acu Train: 0.7089025974273682
# Acu valid: 0.5942249894142151
# tensor(0.7188)
# tensor(0.6719)
# tensor(0.6953)
# tensor(0.7422)
# tensor(0.7500)
# tensor(0.6875)
# tensor(0.7422)
# tensor(0.7891)
# tensor(0.6641)
# Acu Train: 0.7202469110488892
# Acu valid: 0.5865906476974487
# tensor(0.7344)
# tensor(0.7578)
# tensor(0.6328)
# tensor(0.7031)
# tensor(0.7578)
# tensor(0.6328)
# tensor(0.6875)
# tensor(0.7656)
# tensor(0.7031)
# Acu Train: 0.7032727003097534
# Acu valid: 0.5833038091659546
# tensor(0.7500)
# tensor(0.7656)
# tensor(0.7344)
# tensor(0.7266)
# tensor(0.6641)
# tensor(0.7734)
# tensor(0.6953)
# tensor(0.7500)
# tensor(0.6172)
# Acu Train: 0.7232018709182739
# Acu valid: 0.5901511907577515
# tensor(0.7188)
# tensor(0.7422)
# tensor(0.7891)
# tensor(0.7734)
# tensor(0.6562)
# tensor(0.6797)
# tensor(0.6406)
# tensor(0.8438)
# tensor(0.7031)
# Acu Train: 0.7249387502670288
# Acu valid: 0.5846211314201355
# tensor(0.7422)
# tensor(0.7422)
# tensor(0.7422)
# tensor(0.6719)
# tensor(0.8047)
# tensor(0.7812)
# tensor(0.6719)
# tensor(0.6953)
# tensor(0.6250)
# Acu Train: 0.7321716547012329
# Acu valid: 0.5826506614685059
# tensor(0.7031)
# tensor(0.7578)
# tensor(0.7266)
# tensor(0.7734)
# tensor(0.6875)
# tensor(0.6797)
# tensor(0.7344)
# tensor(0.8359)
# tensor(0.7422)
# Acu Train: 0.734178900718689
# Acu valid: 0.594258189201355
# tensor(0.7188)
# tensor(0.7656)
# tensor(0.7500)
# tensor(0.7031)
# tensor(0.7891)
# tensor(0.7891)
# tensor(0.7188)
# tensor(0.6719)
# tensor(0.6953)
# Acu Train: 0.7469161152839661
# Acu valid: 0.5874511003494263
# tensor(0.7578)
# tensor(0.7812)
# tensor(0.6250)
# tensor(0.6953)
# tensor(0.6719)
# tensor(0.7812)
# tensor(0.7344)
# tensor(0.7656)
# tensor(0.7422)
# Acu Train: 0.7471727132797241
# Acu valid: 0.592529296875
# tensor(0.8047)
# tensor(0.7578)
# tensor(0.7578)
# tensor(0.7812)
# tensor(0.7891)
# tensor(0.7344)
# tensor(0.7578)
# tensor(0.7422)
# tensor(0.7891)
# Acu Train: 0.7545812726020813
# Acu valid: 0.5930253863334656
# tensor(0.7969)
# tensor(0.7812)
# tensor(0.8281)
# tensor(0.7734)
# tensor(0.7656)
# tensor(0.7500)
# tensor(0.7344)
# tensor(0.6875)
# tensor(0.7578)
# Acu Train: 0.7596014738082886
# Acu valid: 0.5909683704376221
# tensor(0.7734)
# tensor(0.7578)
# tensor(0.6953)
# tensor(0.7500)
# tensor(0.7656)
# tensor(0.7969)
# tensor(0.7109)
# tensor(0.7344)
# tensor(0.7734)
# Acu Train: 0.7591177225112915
# Acu valid: 0.5595844984054565
# tensor(0.7500)
# tensor(0.7422)
# tensor(0.7578)
# tensor(0.7656)
# tensor(0.7812)
# tensor(0.7500)
# tensor(0.7422)
# tensor(0.7812)
# tensor(0.7734)
# Acu Train: 0.7682744860649109
# Acu valid: 0.5856587290763855
# tensor(0.7031)
# tensor(0.7734)
# tensor(0.7812)
# tensor(0.8047)
# tensor(0.7734)
# tensor(0.7734)
# tensor(0.7344)
# tensor(0.7969)
# tensor(0.7188)
# Acu Train: 0.7518371343612671
# Acu valid: 0.5875678658485413
# tensor(0.7422)
# tensor(0.8516)
# tensor(0.7422)
# tensor(0.7969)
# tensor(0.7109)
# tensor(0.7266)
# tensor(0.7656)
# tensor(0.7812)
# tensor(0.6797)
# Acu Train: 0.7635582685470581
# Acu valid: 0.5902146100997925
# tensor(0.)
# tensor(0.3281)
# tensor(0.3203)
# tensor(0.3984)
# tensor(0.4609)
# tensor(0.5078)
# tensor(0.4844)
# tensor(0.4688)
# tensor(0.4531)
# Acu Train: 0.401350200176239
# Acu valid: 0.461364209651947
# tensor(0.5469)
# tensor(0.5547)
# tensor(0.4609)
# tensor(0.6016)
# tensor(0.6562)
# tensor(0.6484)
# tensor(0.6094)
# tensor(0.5469)
# tensor(0.5938)
# Acu Train: 0.5809208154678345
# Acu valid: 0.5153301358222961
# tensor(0.6406)
# tensor(0.6719)
# tensor(0.7188)
# tensor(0.7188)
# tensor(0.6875)
# tensor(0.6953)
# tensor(0.6953)
# tensor(0.7344)
# tensor(0.6562)
# Acu Train: 0.6785427331924438
# Acu valid: 0.5236810445785522
# tensor(0.6875)
# tensor(0.7031)
# tensor(0.7266)
# tensor(0.7031)
# tensor(0.7578)
# tensor(0.7812)
# tensor(0.7500)
# tensor(0.7969)
# tensor(0.7500)
# Acu Train: 0.7401267290115356
# Acu valid: 0.532103419303894
# tensor(0.8203)
# tensor(0.8359)
# tensor(0.8047)
# tensor(0.7656)
# tensor(0.7656)
# tensor(0.7812)
# tensor(0.7656)
# tensor(0.8203)
# tensor(0.8438)
# Acu Train: 0.7859255075454712
# Acu valid: 0.5246813893318176
# tensor(0.8594)
# tensor(0.8516)
# tensor(0.8281)
# tensor(0.7500)
# tensor(0.8828)
# tensor(0.7656)
# tensor(0.8125)
# tensor(0.8203)
# tensor(0.8125)
# Acu Train: 0.8193546533584595
# Acu valid: 0.5179084539413452
# tensor(0.8438)
# tensor(0.8203)
# tensor(0.8672)
# tensor(0.8281)
# tensor(0.8516)
# tensor(0.8281)
# tensor(0.8750)
# tensor(0.8359)
# tensor(0.8516)
# Acu Train: 0.8459274172782898
# Acu valid: 0.5218947529792786
# tensor(0.8516)
# tensor(0.8438)
# tensor(0.8672)
# tensor(0.8125)
# tensor(0.8516)
# tensor(0.8828)
# tensor(0.8438)
# tensor(0.8750)
# tensor(0.8281)
# Acu Train: 0.8663402795791626
# Acu valid: 0.5139695405960083
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.8750)
# tensor(0.8516)
# tensor(0.8516)
# tensor(0.8750)
# tensor(0.8984)
# tensor(0.8359)
# tensor(0.9062)
# Acu Train: 0.8813386559486389
# Acu valid: 0.5096904039382935
# tensor(0.8828)
# tensor(0.8750)
# tensor(0.8828)
# tensor(0.9219)
# tensor(0.9297)
# tensor(0.9062)
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.9141)
# Acu Train: 0.893456757068634
# Acu valid: 0.5126632452011108
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.9609)
# tensor(0.8984)
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.9141)
# Acu Train: 0.903038501739502
# Acu valid: 0.5149426460266113
# tensor(0.8906)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.8828)
# tensor(0.8672)
# tensor(0.9219)
# tensor(0.8594)
# tensor(0.8750)
# tensor(0.9219)
# Acu Train: 0.9098845720291138
# Acu valid: 0.5082694292068481
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.8516)
# tensor(0.8984)
# tensor(0.9375)
# tensor(0.9453)
# tensor(0.9141)
# tensor(0.8672)
# tensor(0.9531)
# Acu Train: 0.9147762060165405
# Acu valid: 0.5109443068504333
# tensor(0.9609)
# tensor(0.9062)
# tensor(0.9375)
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.8828)
# Acu Train: 0.9201374650001526
# Acu valid: 0.5087010860443115
# tensor(0.8828)
# tensor(0.9297)
# tensor(0.9375)
# tensor(0.8984)
# tensor(0.9141)
# tensor(0.8672)
# tensor(0.8984)
# tensor(0.9766)
# tensor(0.9219)
# Acu Train: 0.9229746460914612
# Acu valid: 0.5091388821601868
# tensor(0.8828)
# tensor(0.9453)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.9609)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.9062)
# Acu Train: 0.9253284335136414
# Acu valid: 0.509406566619873
# tensor(0.9688)
# tensor(0.8906)
# tensor(0.9609)
# tensor(0.8984)
# tensor(0.9375)
# tensor(0.8984)
# tensor(0.9531)
# tensor(0.9219)
# tensor(0.9531)
# Acu Train: 0.9279570579528809
# Acu valid: 0.5058339238166809
# tensor(0.9609)
# tensor(0.9531)
# tensor(0.9453)
# tensor(0.9609)
# tensor(0.9531)
# tensor(0.9688)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9141)
# Acu Train: 0.928629457950592
# Acu valid: 0.5095656514167786
# tensor(0.9609)
# tensor(0.9688)
# tensor(0.8984)
# tensor(0.9688)
# tensor(0.9297)
# tensor(0.9062)
# tensor(0.9219)
# tensor(0.9375)

# %%
from google.colab import runtime
runtime.unassign()
