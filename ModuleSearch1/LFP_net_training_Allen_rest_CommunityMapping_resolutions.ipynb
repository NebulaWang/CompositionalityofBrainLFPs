# %%
# @title Package
from natsort import natsorted
import numpy as np
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import scipy as sp
import scipy.signal as signal
import torchaudio
import math
from sklearn import svm

import torchvision
import torchvision.transforms as transforms
import torchaudio.models as audio_models

from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset

import time

lib_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project44/Code'
os.chdir(lib_dir)
print('library directory: ' + lib_dir)
from modules.networks_clf import *
from modules.signal import spectro_norm, lfp_spectro
from modules.data import *
from modules.metrics import accu_fun
# Out:
# library directory: /content/drive/MyDrive/Project/BrainRegionId/Project44/Code

# %%
# @title Load device
dtype = torch.float
# Check whether GPU is available
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-e50b641e-4373-4921-009e-7bb5dfc3eb1b)

# %%
# Set the signal parameters
spectro_args = {
    'nfft':800,
    'power':1,
    'LFP_bound':[0, 500],
    'MUA_bound':[500, 2000],
    'spectro_img':[224, 28],
    'LFP_img':[56 * 4, 28],
    'MUA_img':[0, 28],
    'sampling_lfp':2500,
    'sampling_mua':5000,
    'Log':False,
}

dict_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project37/Data/dat'
acronym_list = acronym_list_gen(dict_dir)

# %%
# @title Load data
file_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project43/Data/dat/completed/'
brain_signal_lfp = torch.load('/content/drive/MyDrive/Project/BrainRegionId/Project43/Result/brain_signal_lfp/brain_signal_lfp.pt', weights_only=False)
list_dict = torch.load(file_dir + '/list_dict.pt', weights_only=False)

brain_region_index = list_dict['brain_region_index']
brain_region_index_Cosmos = list_dict['brain_region_index_Cosmos']
coordinate_list = list_dict['coordinate_list']
acronym_selec_list = list_dict['acronym_selec_list']

# %%
if len(brain_signal_lfp) == len(brain_region_index):
    print('Matched, no damage!')
# Out:
# Matched, no damage!

# %%
community_dict = torch.load('/content/drive/MyDrive/Project/BrainRegionId/Science/results/communities/community_dict.pt', weights_only=False)

# %%
def iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index0, coordinate_list):
    data_train = TensorDataset(brain_signal_lfp[train_ind,:], brain_region_index0[train_ind], coordinate_list[train_ind])
    data_valid = TensorDataset(brain_signal_lfp[valid_ind,:], brain_region_index0[valid_ind], coordinate_list[valid_ind])
    data_test = TensorDataset(brain_signal_lfp[test_ind,:], brain_region_index0[test_ind], coordinate_list[test_ind])

    train_iter = DataLoader(data_train, batch_size=128, shuffle=True)
    valid_iter = DataLoader(data_valid, batch_size=128, shuffle=True)
    test_iter = DataLoader(data_test, batch_size=128, shuffle=True)

    return train_iter, valid_iter, test_iter

# %%
# @title Training function
def net_train_AnyNet_L(train_iter, valid_iter, Classifier, spectro_args, train_args, key, ind, resolution, device):
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(Classifier.parameters(), train_args['lr'])
    # print('lr: ' + train_args['lr'])
    acu_array_train = []
    acu_array_valid = []
    time_array_train = []
    time_array_valid = []
    acu_valid_max = 0
    for epoch in range(0, train_args['epochs']):
        Classifier.train()
        acu_train = []
        epoch0 = 0
        time0_train = time.time()
        for x_train1, y_train, coordinate_train in train_iter:
            x_train = lfp_spectro(x_train1, spectro_args, train_args)
            y_train = y_train.to(device)
            py_train = Classifier(x_train.to(device))
            del x_train, x_train1
            if epoch0 % 800 == 0:
                if epoch0 == 0 and epoch == 0:
                    if accu_fun(py_train, y_train) == (torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu():
                        print('accu_fun is correct>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
                    else:
                        print('accu_fun is wrong>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
                        return
                print(accu_fun(py_train, y_train))
            # print(y_train.size())
            L = loss_fn(py_train,y_train.to(device))
            optimizer.zero_grad()
            L.backward()
            optimizer.step()
            acu_train.append(accu_fun(py_train, y_train))
            epoch0 += 1
        print(f'Acu Train: {torch.mean(torch.tensor(acu_train))}')

        acu_array_train.append(torch.mean(torch.tensor(acu_train)))
        time_array_train.append(time.time() - time0_train)

        Classifier.eval()
        acu_valid = []
        time0_valid = time.time()
        for x_valid1, y_valid, coordinate_valid in valid_iter:
            x_valid = lfp_spectro(x_valid1, spectro_args, train_args)
            y_valid = y_valid.to(device)
            py_valid = Classifier(x_valid.to(device))
            del x_valid, x_valid1
            acu_valid.append(accu_fun(py_valid, y_valid))
            # acu_valid.append((torch.sum(torch.argmax(py_valid, dim=1) == y_valid) / y_valid.size(0)).detach().cpu())

        print(f'Acu valid: {torch.mean(torch.tensor(acu_valid))}')
        if torch.mean(torch.tensor(acu_train)) > train_args['overfitting_thres']:
            if acu_valid_max < torch.mean(torch.tensor(acu_valid)):
                torch.save(Classifier, train_args['save_dir'] + f'/Model/Community/{resolution}/AnyNet_L_AllenCommunity_{key}_{ind}.pth')
                torch.save(epoch, train_args['save_dir'] + f'/Model/Community/{resolution}/AnyNet_L_AllenCommunity_{key}_epoch{ind}.pt')
                acu_valid_max = torch.mean(torch.tensor(acu_valid))

        acu_array_valid.append(torch.mean(torch.tensor(acu_valid)))
        time_array_valid.append(time.time() - time0_valid)

    torch.save(acu_array_train, train_args['save_dir'] + f'/Model/Community/{resolution}/AnyNet_L_AllenCommunity_{key}_train_acu{ind}.pt')
    torch.save(acu_array_valid, train_args['save_dir'] + f'/Model/Community/{resolution}/AnyNet_L_AllenCommunity_{key}_valid_acu{ind}.pt')

    return


def net_train_ViT_L(train_iter, valid_iter, Classifier, spectro_args, train_args, key, ind, resolution, device):
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(Classifier.parameters(), train_args['lr'])
    # print('lr: ' + train_args['lr'])
    acu_array_train = []
    acu_array_valid = []
    time_array_train = []
    time_array_valid = []
    acu_valid_max = 0
    for epoch in range(0, train_args['epochs']):
        Classifier.train()
        acu_train = []
        epoch0 = 0
        time0_train = time.time()
        for x_train1, y_train, coordinate_train in train_iter:
            x_train = lfp_spectro(x_train1, spectro_args, train_args)
            y_train = y_train.to(device)
            py_train = Classifier(x_train.to(device))
            del x_train, x_train1
            if epoch0 % 800 == 0:
                print((torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu())
            L = loss_fn(py_train,y_train.to(device))
            optimizer.zero_grad()
            L.backward()
            optimizer.step()
            acu_train.append((torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu())
            epoch0 += 1
        print(f'Acu Train: {torch.mean(torch.tensor(acu_train))}')

        acu_array_train.append(torch.mean(torch.tensor(acu_train)))
        time_array_train.append(time.time() - time0_train)

        Classifier.eval()
        acu_valid = []
        time0_valid = time.time()
        for x_valid1, y_valid, coordinate_valid in valid_iter:
            x_valid = lfp_spectro(x_valid1, spectro_args, train_args)
            y_valid = y_valid.to(device)
            py_valid = Classifier(x_valid.to(device))
            del x_valid, x_valid1
            acu_valid.append((torch.sum(torch.argmax(py_valid, dim=1) == y_valid) / y_valid.size(0)).detach().cpu())

        print(f'Acu valid: {torch.mean(torch.tensor(acu_valid))}')
        if torch.mean(torch.tensor(acu_train)) > train_args['overfitting_thres']:
            if acu_valid_max < torch.mean(torch.tensor(acu_valid)):
                torch.save(Classifier, train_args['save_dir'] + f'/Model/Community/{resolution}/ViT_L_AllenCommunity_{key}_{ind}.pth')
                torch.save(epoch, train_args['save_dir'] + f'/Model/Community/{resolution}/ViT_L_AllenCommunity_{key}_epoch{ind}.pt')
                acu_valid_max = torch.mean(torch.tensor(acu_valid))

        acu_array_valid.append(torch.mean(torch.tensor(acu_valid)))
        time_array_valid.append(time.time() - time0_valid)

    torch.save(torch.tensor(acu_array_train), train_args['save_dir'] + f'/Model/Community/{resolution}/ViT_L_AllenCommunity_{key}_train_acu{ind}.pt')
    torch.save(torch.tensor(acu_array_valid), train_args['save_dir'] + f'/Model/Community/{resolution}/ViT_L_AllenCommunity_{key}_valid_acu{ind}.pt')

    return

def net_train_RNN_L(train_iter, valid_iter, Classifier, spectro_args, train_args, key, ind, resolution, device):
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(Classifier.parameters(), train_args['lr'])
    # print('lr: ' + train_args['lr'])
    acu_array_train = []
    acu_array_valid = []
    time_array_train = []
    time_array_valid = []
    acu_valid_max = 0
    for epoch in range(0, train_args['epochs']):
        Classifier.train()
        acu_train = []
        time0_train = time.time()
        epoch0 = 0
        for x_train1, y_train, coordinate_train in train_iter:
            x_train = lfp_spectro(x_train1, spectro_args, train_args).squeeze(1).permute(0, 2, 1)
            y_train = y_train.to(device)
            py_train = Classifier(x_train.to(device))
            del x_train, x_train1
            if epoch0 % 800 == 0:
                print((torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu())
            L = loss_fn(py_train,y_train.to(device))
            optimizer.zero_grad()
            L.backward()
            optimizer.step()
            acu_train.append((torch.sum(torch.argmax(py_train, dim=1) == y_train) / y_train.size(0)).detach().cpu())
            epoch0 += 1
        print(f'Acu Train: {torch.mean(torch.tensor(acu_train))}')

        acu_array_train.append(torch.mean(torch.tensor(acu_train)))
        time_array_train.append(time.time() - time0_train)

        Classifier.eval()
        acu_valid = []
        time0_valid = time.time()
        for x_valid1, y_valid, coordinate_valid in valid_iter:
            x_valid = lfp_spectro(x_valid1, spectro_args, train_args).squeeze(1).permute(0, 2, 1)
            y_valid = y_valid.to(device)
            py_valid = Classifier(x_valid.to(device))
            del x_valid, x_valid1
            acu_valid.append((torch.sum(torch.argmax(py_valid, dim=1) == y_valid) / y_valid.size(0)).detach().cpu())

        print(f'Acu valid: {torch.mean(torch.tensor(acu_valid))}')
        if torch.mean(torch.tensor(acu_train)) > train_args['overfitting_thres']:
            if acu_valid_max < torch.mean(torch.tensor(acu_valid)):
                torch.save(Classifier, train_args['save_dir'] + f'/Model/Community/{resolution}/RNN_L_AllenCommunity_{key}_{ind}.pth')
                torch.save(epoch, train_args['save_dir'] + f'/Model/Community/{resolution}/RNN_L_AllenCommunity_{key}_epoch{ind}.pt')
                acu_valid_max = torch.mean(torch.tensor(acu_valid))


        acu_array_valid.append(torch.mean(torch.tensor(acu_valid)))
        time_array_valid.append(time.time() - time0_valid)

    torch.save(torch.tensor(acu_array_train), train_args['save_dir'] + f'/Model/Community/{resolution}/RNN_L_AllenCommunity_{key}_train_acu{ind}.pt')
    torch.save(torch.tensor(acu_array_valid), train_args['save_dir'] + f'/Model/Community/{resolution}/RNN_L_AllenCommunity_{key}_valid_acu{ind}.pt')

    return

# %%
save_dir = '/content/drive/MyDrive/Project/BrainRegionId/Science/'

for resolution in [0.8, 1.0, 1.2]:
    communities = community_dict[resolution]['communities']
    communities_label = community_dict[resolution]['communities_label']
    communities_acronym = community_dict[resolution]['communities_acronym']

    id_community_mapping = []
    for acronym in acronym_list:
        if acronym in communities_acronym:
            id_community_mapping.append(communities_label[np.argwhere(communities_acronym == acronym).flatten()])
        else:
            id_community_mapping.append(np.array([-1]))

    id_community_mapping = np.array(id_community_mapping)

    brain_region_index_intersect = id_community_mapping[brain_region_index].squeeze(-1)
    dropout_index = np.argwhere(brain_region_index_intersect == np.array([-1]))[:, 0]

    brain_region_index_intersect = torch.tensor(brain_region_index_intersect, dtype=torch.long)

    key = 'stimOff_times'
    model_dir = '/content/drive/MyDrive/Project/BrainRegionId/Project44/Model/Allen'
    subject_od_ind = torch.load(model_dir + f'/subject_od_ind_Allen_{key}{0}.pt', weights_only=False)
    subject_od_list = torch.load(model_dir + f'/subject_od_list_Allen_{key}{0}.pt', weights_only=False)
    train_ind, valid_ind, test_ind, test_subject_ind = dat_ind_gen(list_dict, subject_od_ind, key)
    train_ind = np.setdiff1d(train_ind, dropout_index)
    valid_ind = np.setdiff1d(valid_ind, dropout_index)
    test_ind = np.setdiff1d(test_ind, dropout_index)
    train_iter_AnyNet, valid_iter_AnyNet, test_iter_AnyNet = iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index_intersect, coordinate_list)

    c0 = 64 * 4
    k0 = 1.0

    model_args = {
        'arch':((2,c0 * 2,1,k0), (2,c0 * 3,1,k0), (2,c0 * 4,1,k0), (2,c0 * 5,1,k0)),
        'stem_channels':c0,
    }
    train_args = {
        'overfitting_thres':0.60,
        'lr':5e-4,
        'norm':True,
        'temp':[True, True],
        'epochs':10,
        'save_dir':save_dir,
    }


    for ind in range(0, 1):
        Classifier = AnyNet_L(model_args['arch'], model_args['stem_channels'], frequency_bin=spectro_args['spectro_img'][0], num_classes=len(np.unique(communities_label))).to(device)
        Classifier.apply(init_cnn)
        net_train_AnyNet_L(train_iter_AnyNet, valid_iter_AnyNet, Classifier.to(device), spectro_args, train_args, key, ind, resolution, device)

    train_iter_ViT, valid_iter_ViT, test_iter_ViT = iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index_intersect, coordinate_list)

    train_args['epochs'] = 50
    for ind in range(0, 1):
        img_size, patch_size = (224, 28), (28, 28)
        num_hiddens, mlp_num_hiddens, num_heads, num_blks = 512, 2048, 8, 4
        emb_dropout, blk_dropout = 0.1, 0.1
        Classifier = ViT_L(spectro_args['spectro_img'][0], img_size, patch_size, num_hiddens, mlp_num_hiddens, num_heads, num_blks, emb_dropout, blk_dropout, num_classes=len(np.unique(communities_label))).to(device)
        net_train_ViT_L(train_iter_ViT, valid_iter_ViT, Classifier.to(device), spectro_args, train_args, key, ind, resolution, device)

    del train_iter_ViT, valid_iter_ViT, test_iter_ViT
    train_iter_RNN, valid_iter_RNN, test_iter_RNN = iter_gen(train_ind, valid_ind, test_ind, brain_signal_lfp, brain_region_index_intersect, coordinate_list)
    train_args['epochs'] = 30

    RNN_args = {
    'input_size':224,
    'hidden_size':512 * 2,
    'num_layers':2,
    'category_num':len(np.unique(communities_label)),
    'data_len':28,
    }
    for ind in range(0, 1):
        Classifier = RNN_L(spectro_args['spectro_img'][0], RNN_args).to(device)
        net_train_RNN_L(train_iter_RNN, valid_iter_RNN, Classifier.to(device), spectro_args, train_args, key, ind, resolution, device)
# Out:
# accu_fun is correct>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# tensor(0.0312)
# tensor(0.3438)
# tensor(0.3516)
# tensor(0.5859)
# tensor(0.3984)
# tensor(0.4375)
# tensor(0.5391)
# tensor(0.5078)
# tensor(0.4844)
# tensor(0.5156)
# tensor(0.5547)
# Acu Train: 0.4918726682662964
# Acu valid: 0.5276463031768799
# tensor(0.6016)
# tensor(0.6094)
# tensor(0.5625)
# tensor(0.6172)
# tensor(0.5547)
# tensor(0.7109)
# tensor(0.6562)
# tensor(0.6875)
# tensor(0.6250)
# tensor(0.6250)
# tensor(0.6250)
# Acu Train: 0.6315704584121704
# Acu valid: 0.5661640763282776
# tensor(0.6016)
# tensor(0.7266)
# tensor(0.7188)
# tensor(0.6797)
# tensor(0.7266)
# tensor(0.7578)
# tensor(0.7031)
# tensor(0.7266)
# tensor(0.6875)
# tensor(0.7188)
# tensor(0.7266)
# Acu Train: 0.7085856795310974
# Acu valid: 0.5728073716163635
# tensor(0.7500)
# tensor(0.7969)
# tensor(0.7734)
# tensor(0.7969)
# tensor(0.8125)
# tensor(0.7969)
# tensor(0.7422)
# tensor(0.7031)
# tensor(0.8516)
# tensor(0.8516)
# tensor(0.7891)
# Acu Train: 0.7683981657028198
# Acu valid: 0.571338415145874
# tensor(0.8125)
# tensor(0.7891)
# tensor(0.7656)
# tensor(0.7734)
# tensor(0.8203)
# tensor(0.7891)
# tensor(0.7578)
# tensor(0.8203)
# tensor(0.7969)
# tensor(0.7969)
# tensor(0.8359)
# Acu Train: 0.8153405785560608
# Acu valid: 0.5569204688072205
# tensor(0.8906)
# tensor(0.8750)
# tensor(0.8203)
# tensor(0.8359)
# tensor(0.8203)
# tensor(0.8750)
# tensor(0.8594)
# tensor(0.8281)
# tensor(0.8516)
# tensor(0.8047)
# tensor(0.8594)
# Acu Train: 0.8510750532150269
# Acu valid: 0.5490612387657166
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.9219)
# tensor(0.8750)
# tensor(0.8828)
# tensor(0.9219)
# tensor(0.9141)
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.8750)
# tensor(0.8672)
# Acu Train: 0.8774575591087341
# Acu valid: 0.5352147817611694
# tensor(0.9219)
# tensor(0.9062)
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.8828)
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.9141)
# tensor(0.9219)
# Acu Train: 0.8975005149841309
# Acu valid: 0.5236091017723083
# tensor(0.9062)
# tensor(0.8828)
# tensor(0.9453)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.8828)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.8906)
# Acu Train: 0.9122821688652039
# Acu valid: 0.5490301251411438
# tensor(0.9531)
# tensor(0.9609)
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9453)
# tensor(0.9375)
# tensor(0.9297)
# tensor(0.9453)
# tensor(0.9062)
# Acu Train: 0.9239310026168823
# Acu valid: 0.45897340774536133
# tensor(0.0234)
# tensor(0.2812)
# tensor(0.3906)
# tensor(0.3516)
# tensor(0.3047)
# tensor(0.3828)
# tensor(0.4141)
# tensor(0.3125)
# tensor(0.4375)
# tensor(0.3672)
# tensor(0.3359)
# Acu Train: 0.35771414637565613
# Acu valid: 0.42359402775764465
# tensor(0.4375)
# tensor(0.4531)
# tensor(0.4531)
# tensor(0.3672)
# tensor(0.3906)
# tensor(0.3438)
# tensor(0.4609)
# tensor(0.4688)
# tensor(0.4062)
# tensor(0.5000)
# tensor(0.4062)
# Acu Train: 0.42830514907836914
# Acu valid: 0.4709203243255615
# tensor(0.4453)
# tensor(0.3516)
# tensor(0.4219)
# tensor(0.4062)
# tensor(0.5156)
# tensor(0.4141)
# tensor(0.4531)
# tensor(0.3906)
# tensor(0.4844)
# tensor(0.5078)
# tensor(0.5000)
# Acu Train: 0.4663802981376648
# Acu valid: 0.49315208196640015
# tensor(0.4375)
# tensor(0.5078)
# tensor(0.4922)
# tensor(0.4844)
# tensor(0.4688)
# tensor(0.5078)
# tensor(0.4688)
# tensor(0.4531)
# tensor(0.5234)
# tensor(0.5391)
# tensor(0.5000)
# Acu Train: 0.47634899616241455
# Acu valid: 0.5083629488945007
# tensor(0.4375)
# tensor(0.4141)
# tensor(0.4609)
# tensor(0.5625)
# tensor(0.4453)
# tensor(0.4375)
# tensor(0.4531)
# tensor(0.5391)
# tensor(0.4766)
# tensor(0.5391)
# tensor(0.5469)
# Acu Train: 0.4864952564239502
# Acu valid: 0.5116173624992371
# tensor(0.4844)
# tensor(0.5234)
# tensor(0.5078)
# tensor(0.4141)
# tensor(0.5625)
# tensor(0.5000)
# tensor(0.5391)
# tensor(0.5547)
# tensor(0.4297)
# tensor(0.4922)
# tensor(0.5078)
# Acu Train: 0.505854606628418
# Acu valid: 0.5257041454315186
# tensor(0.5391)
# tensor(0.5391)
# tensor(0.4844)
# tensor(0.5391)
# tensor(0.5547)
# tensor(0.5078)
# tensor(0.5391)
# tensor(0.5547)
# tensor(0.5938)
# tensor(0.4766)
# tensor(0.4688)
# Acu Train: 0.5238048434257507
# Acu valid: 0.4592524468898773
# tensor(0.4844)
# tensor(0.5625)
# tensor(0.5547)
# tensor(0.5391)
# tensor(0.4531)
# tensor(0.5859)
# tensor(0.5000)
# tensor(0.4844)
# tensor(0.5469)
# tensor(0.5781)
# tensor(0.4297)
# Acu Train: 0.529712975025177
# Acu valid: 0.5477375388145447
# tensor(0.5703)
# tensor(0.5469)
# tensor(0.4219)
# tensor(0.6172)
# tensor(0.5156)
# tensor(0.5859)
# tensor(0.5781)
# tensor(0.5703)
# tensor(0.5547)
# tensor(0.6016)
# tensor(0.6016)
# Acu Train: 0.5509344935417175
# Acu valid: 0.5508737564086914
# tensor(0.6328)
# tensor(0.5859)
# tensor(0.5312)
# tensor(0.5703)
# tensor(0.5234)
# tensor(0.5469)
# tensor(0.5781)
# tensor(0.5078)
# tensor(0.5156)
# tensor(0.4922)
# tensor(0.4922)
# Acu Train: 0.5641696453094482
# Acu valid: 0.5484573841094971
# tensor(0.5469)
# tensor(0.5312)
# tensor(0.5703)
# tensor(0.4297)
# tensor(0.5547)
# tensor(0.4922)
# tensor(0.6172)
# tensor(0.5547)
# tensor(0.5078)
# tensor(0.5703)
# tensor(0.5312)
# Acu Train: 0.5717195272445679
# Acu valid: 0.5702518224716187
# tensor(0.5938)
# tensor(0.5469)
# tensor(0.6641)
# tensor(0.5391)
# tensor(0.4922)
# tensor(0.6094)
# tensor(0.5938)
# tensor(0.5547)
# tensor(0.6094)
# tensor(0.5938)
# tensor(0.5859)
# Acu Train: 0.5819662809371948
# Acu valid: 0.5781002044677734
# tensor(0.5938)
# tensor(0.5078)
# tensor(0.5156)
# tensor(0.5078)
# tensor(0.6328)
# tensor(0.6094)
# tensor(0.5625)
# tensor(0.5703)
# tensor(0.4922)
# tensor(0.5156)
# tensor(0.5625)
# Acu Train: 0.5830700397491455
# Acu valid: 0.5727609395980835
# tensor(0.6016)
# tensor(0.5625)
# tensor(0.5156)
# tensor(0.5859)
# tensor(0.5234)
# tensor(0.5703)
# tensor(0.5391)
# tensor(0.4922)
# tensor(0.5625)
# tensor(0.6094)
# tensor(0.5781)
# Acu Train: 0.5686865448951721
# Acu valid: 0.5800493359565735
# tensor(0.7031)
# tensor(0.5781)
# tensor(0.5703)
# tensor(0.6172)
# tensor(0.6016)
# tensor(0.6172)
# tensor(0.4766)
# tensor(0.4531)
# tensor(0.5469)
# tensor(0.5078)
# tensor(0.4219)
# Acu Train: 0.5291189551353455
# Acu valid: 0.5471629500389099
# tensor(0.5469)
# tensor(0.4688)
# tensor(0.5547)
# tensor(0.5547)
# tensor(0.6094)
# tensor(0.4922)
# tensor(0.5000)
# tensor(0.4844)
# tensor(0.5312)
# tensor(0.5312)
# tensor(0.5859)
# Acu Train: 0.5341286659240723
# Acu valid: 0.5676660537719727
# tensor(0.5938)
# tensor(0.4922)
# tensor(0.5078)
# tensor(0.5234)
# tensor(0.6484)
# tensor(0.5156)
# tensor(0.4766)
# tensor(0.4922)
# tensor(0.5547)
# tensor(0.5859)
# tensor(0.5156)
# Acu Train: 0.5681915283203125
# Acu valid: 0.5739219188690186
# tensor(0.5703)
# tensor(0.4844)
# tensor(0.5078)
# tensor(0.5625)
# tensor(0.5625)
# tensor(0.5703)
# tensor(0.5938)
# tensor(0.5156)
# tensor(0.6094)
# tensor(0.5469)
# tensor(0.6484)
# Acu Train: 0.5793324708938599
# Acu valid: 0.5637664794921875
# tensor(0.5938)
# tensor(0.6016)
# tensor(0.6094)
# tensor(0.6016)
# tensor(0.5781)
# tensor(0.5781)
# tensor(0.5938)
# tensor(0.5938)
# tensor(0.4922)
# tensor(0.6875)
# tensor(0.6094)
# Acu Train: 0.5887703895568848
# Acu valid: 0.5764860510826111
# tensor(0.5312)
# tensor(0.6562)
# tensor(0.6016)
# tensor(0.6328)
# tensor(0.5391)
# tensor(0.6328)
# tensor(0.5703)
# tensor(0.5547)
# tensor(0.5938)
# tensor(0.6250)
# tensor(0.6094)
# Acu Train: 0.598548948764801
# Acu valid: 0.5569493770599365
# tensor(0.5312)
# tensor(0.5469)
# tensor(0.5938)
# tensor(0.6328)
# tensor(0.4922)
# tensor(0.6016)
# tensor(0.6094)
# tensor(0.5625)
# tensor(0.7031)
# tensor(0.6172)
# tensor(0.5938)
# Acu Train: 0.6109024286270142
# Acu valid: 0.5919795036315918
# tensor(0.5781)
# tensor(0.6016)
# tensor(0.6406)
# tensor(0.5703)
# tensor(0.5078)
# tensor(0.5625)
# tensor(0.5859)
# tensor(0.5859)
# tensor(0.6250)
# tensor(0.4297)
# tensor(0.5938)
# Acu Train: 0.597381591796875
# Acu valid: 0.5364780426025391
# tensor(0.5312)
# tensor(0.5703)
# tensor(0.5469)
# tensor(0.6328)
# tensor(0.6094)
# tensor(0.5703)
# tensor(0.5703)
# tensor(0.5391)
# tensor(0.5859)
# tensor(0.6406)
# tensor(0.6094)
# Acu Train: 0.5694499015808105
# Acu valid: 0.5723569989204407
# tensor(0.6484)
# tensor(0.5625)
# tensor(0.6172)
# tensor(0.5859)
# tensor(0.5469)
# tensor(0.6172)
# tensor(0.5859)
# tensor(0.6094)
# tensor(0.5703)
# tensor(0.5312)
# tensor(0.6094)
# Acu Train: 0.5886374711990356
# Acu valid: 0.5867844820022583
# tensor(0.5625)
# tensor(0.6641)
# tensor(0.5625)
# tensor(0.6641)
# tensor(0.6094)
# tensor(0.4688)
# tensor(0.5156)
# tensor(0.6250)
# tensor(0.6328)
# tensor(0.6172)
# tensor(0.5781)
# Acu Train: 0.5995539426803589
# Acu valid: 0.5814414024353027
# tensor(0.6016)
# tensor(0.5000)
# tensor(0.6172)
# tensor(0.5859)
# tensor(0.6953)
# tensor(0.5703)
# tensor(0.6094)
# tensor(0.6328)
# tensor(0.6250)
# tensor(0.5859)
# tensor(0.6797)
# Acu Train: 0.6107409596443176
# Acu valid: 0.598312258720398
# tensor(0.6406)
# tensor(0.6094)
# tensor(0.5781)
# tensor(0.6172)
# tensor(0.6172)
# tensor(0.6562)
# tensor(0.5938)
# tensor(0.6250)
# tensor(0.6484)
# tensor(0.6016)
# tensor(0.6328)
# Acu Train: 0.6231479048728943
# Acu valid: 0.5805139541625977
# tensor(0.5938)
# tensor(0.5938)
# tensor(0.5781)
# tensor(0.5781)
# tensor(0.6641)
# tensor(0.5938)
# tensor(0.6953)
# tensor(0.6250)
# tensor(0.6094)
# tensor(0.5703)
# tensor(0.6484)
# Acu Train: 0.6057698130607605
# Acu valid: 0.5884987711906433
# tensor(0.6797)
# tensor(0.5547)
# tensor(0.6484)
# tensor(0.6875)
# tensor(0.5938)
# tensor(0.6641)
# tensor(0.5781)
# tensor(0.6797)
# tensor(0.6328)
# tensor(0.6328)
# tensor(0.5938)
# Acu Train: 0.6269783973693848
# Acu valid: 0.5997039079666138
# tensor(0.7188)
# tensor(0.6641)
# tensor(0.5391)
# tensor(0.6875)
# tensor(0.6328)
# tensor(0.6250)
# tensor(0.6016)
# tensor(0.6016)
# tensor(0.5781)
# tensor(0.6016)
# tensor(0.6719)
# Acu Train: 0.6290766000747681
# Acu valid: 0.6010969281196594
# tensor(0.6094)
# tensor(0.6797)
# tensor(0.6328)
# tensor(0.6406)
# tensor(0.6562)
# tensor(0.5781)
# tensor(0.7031)
# tensor(0.6641)
# tensor(0.6250)
# tensor(0.6641)
# tensor(0.6094)
# Acu Train: 0.634756863117218
# Acu valid: 0.5954127907752991
# tensor(0.6641)
# tensor(0.6953)
# tensor(0.6016)
# tensor(0.7344)
# tensor(0.6250)
# tensor(0.6641)
# tensor(0.6016)
# tensor(0.6016)
# tensor(0.6250)
# tensor(0.6094)
# tensor(0.7109)
# Acu Train: 0.6401475667953491
# Acu valid: 0.602869987487793
# tensor(0.6484)
# tensor(0.6953)
# tensor(0.6562)
# tensor(0.7109)
# tensor(0.7109)
# tensor(0.6094)
# tensor(0.6719)
# tensor(0.6094)
# tensor(0.5938)
# tensor(0.6328)
# tensor(0.6328)
# Acu Train: 0.6387828588485718
# Acu valid: 0.5904721021652222
# tensor(0.6562)
# tensor(0.6094)
# tensor(0.6719)
# tensor(0.6875)
# tensor(0.6484)
# tensor(0.6719)
# tensor(0.5625)
# tensor(0.7266)
# tensor(0.6562)
# tensor(0.5703)
# tensor(0.5859)
# Acu Train: 0.6371228098869324
# Acu valid: 0.5992103815078735
# tensor(0.6953)
# tensor(0.5859)
# tensor(0.6484)
# tensor(0.6875)
# tensor(0.6172)
# tensor(0.5938)
# tensor(0.6406)
# tensor(0.7344)
# tensor(0.6641)
# tensor(0.6875)
# tensor(0.6484)
# Acu Train: 0.6452688574790955
# Acu valid: 0.6052437424659729
# tensor(0.6562)
# tensor(0.6328)
# tensor(0.6875)
# tensor(0.5859)
# tensor(0.6016)
# tensor(0.6641)
# tensor(0.6953)
# tensor(0.6562)
# tensor(0.6406)
# tensor(0.6328)
# tensor(0.5859)
# Acu Train: 0.6537851095199585
# Acu valid: 0.6045680642127991
# tensor(0.6797)
# tensor(0.6719)
# tensor(0.6797)
# tensor(0.6641)
# tensor(0.6328)
# tensor(0.6484)
# tensor(0.6641)
# tensor(0.6016)
# tensor(0.5781)
# tensor(0.6875)
# tensor(0.6562)
# Acu Train: 0.6605798006057739
# Acu valid: 0.6014623641967773
# tensor(0.6172)
# tensor(0.6953)
# tensor(0.6250)
# tensor(0.6484)
# tensor(0.6406)
# tensor(0.5938)
# tensor(0.5859)
# tensor(0.6406)
# tensor(0.5859)
# tensor(0.6562)
# tensor(0.7422)
# Acu Train: 0.6610866189002991
# Acu valid: 0.6061790585517883
# tensor(0.6953)
# tensor(0.6797)
# tensor(0.6250)
# tensor(0.6484)
# tensor(0.5703)
# tensor(0.7266)
# tensor(0.6719)
# tensor(0.6484)
# tensor(0.6719)
# tensor(0.6562)
# tensor(0.6094)
# Acu Train: 0.6600474715232849
# Acu valid: 0.604791522026062
# tensor(0.7109)
# tensor(0.6094)
# tensor(0.6484)
# tensor(0.7344)
# tensor(0.6406)
# tensor(0.7109)
# tensor(0.6875)
# tensor(0.6953)
# tensor(0.7422)
# tensor(0.7812)
# tensor(0.7188)
# Acu Train: 0.6644977927207947
# Acu valid: 0.6040008068084717
# tensor(0.6250)
# tensor(0.6719)
# tensor(0.6719)
# tensor(0.6953)
# tensor(0.7031)
# tensor(0.6406)
# tensor(0.6719)
# tensor(0.6797)
# tensor(0.6016)
# tensor(0.6562)
# tensor(0.6328)
# Acu Train: 0.6543117761611938
# Acu valid: 0.5857064723968506
# tensor(0.5781)
# tensor(0.6719)
# tensor(0.7109)
# tensor(0.6953)
# tensor(0.7344)
# tensor(0.7031)
# tensor(0.7031)
# tensor(0.6953)
# tensor(0.6562)
# tensor(0.6797)
# tensor(0.6484)
# Acu Train: 0.6596540212631226
# Acu valid: 0.6015911102294922
# tensor(0.5859)
# tensor(0.7031)
# tensor(0.6562)
# tensor(0.6094)
# tensor(0.6406)
# tensor(0.6641)
# tensor(0.6562)
# tensor(0.6328)
# tensor(0.6562)
# tensor(0.6562)
# tensor(0.6875)
# Acu Train: 0.6655334234237671
# Acu valid: 0.6051995158195496
# tensor(0.6016)
# tensor(0.6953)
# tensor(0.6797)
# tensor(0.6328)
# tensor(0.6484)
# tensor(0.5625)
# tensor(0.6953)
# tensor(0.5781)
# tensor(0.4922)
# tensor(0.5234)
# tensor(0.5469)
# Acu Train: 0.6179541945457458
# Acu valid: 0.5821037292480469
# tensor(0.6641)
# tensor(0.5547)
# tensor(0.5703)
# tensor(0.5625)
# tensor(0.6016)
# tensor(0.6406)
# tensor(0.6797)
# tensor(0.5859)
# tensor(0.5703)
# tensor(0.6562)
# tensor(0.6016)
# Acu Train: 0.6137900352478027
# Acu valid: 0.5985715389251709
# tensor(0.6562)
# tensor(0.6250)
# tensor(0.6094)
# tensor(0.6016)
# tensor(0.6406)
# tensor(0.6016)
# tensor(0.6953)
# tensor(0.6484)
# tensor(0.6641)
# tensor(0.6172)
# tensor(0.5938)
# Acu Train: 0.633675754070282
# Acu valid: 0.5892618298530579
# tensor(0.6953)
# tensor(0.6719)
# tensor(0.7422)
# tensor(0.5938)
# tensor(0.5938)
# tensor(0.6250)
# tensor(0.6250)
# tensor(0.6328)
# tensor(0.7188)
# tensor(0.6016)
# tensor(0.6562)
# Acu Train: 0.6415700912475586
# Acu valid: 0.5564463138580322
# tensor(0.5156)
# tensor(0.6562)
# tensor(0.7500)
# tensor(0.6875)
# tensor(0.6719)
# tensor(0.7188)
# tensor(0.6094)
# tensor(0.6797)
# tensor(0.5938)
# tensor(0.6562)
# tensor(0.6797)
# Acu Train: 0.6618342399597168
# Acu valid: 0.6071305871009827
# tensor(0.6250)
# tensor(0.7031)
# tensor(0.6953)
# tensor(0.7109)
# tensor(0.6562)
# tensor(0.5938)
# tensor(0.5859)
# tensor(0.6250)
# tensor(0.6797)
# tensor(0.6250)
# tensor(0.6719)
# Acu Train: 0.6465850472450256
# Acu valid: 0.5962390899658203
# tensor(0.6328)
# tensor(0.6484)
# tensor(0.6797)
# tensor(0.6875)
# tensor(0.6719)
# tensor(0.6094)
# tensor(0.6250)
# tensor(0.6484)
# tensor(0.7969)
# tensor(0.7344)
# tensor(0.5938)
# Acu Train: 0.6605159640312195
# Acu valid: 0.6097955107688904
# tensor(0.)
# tensor(0.2734)
# tensor(0.2891)
# tensor(0.3516)
# tensor(0.4922)
# tensor(0.5156)
# tensor(0.5000)
# tensor(0.5391)
# tensor(0.4609)
# tensor(0.5547)
# tensor(0.5547)
# Acu Train: 0.4519270956516266
# Acu valid: 0.514658510684967
# tensor(0.5234)
# tensor(0.5547)
# tensor(0.5078)
# tensor(0.5391)
# tensor(0.6406)
# tensor(0.6094)
# tensor(0.5703)
# tensor(0.6797)
# tensor(0.5469)
# tensor(0.6484)
# tensor(0.6562)
# Acu Train: 0.6064664721488953
# Acu valid: 0.5568174719810486
# tensor(0.6406)
# tensor(0.6328)
# tensor(0.6562)
# tensor(0.6406)
# tensor(0.6719)
# tensor(0.6406)
# tensor(0.6172)
# tensor(0.7109)
# tensor(0.6797)
# tensor(0.6719)
# tensor(0.7344)
# Acu Train: 0.6774189472198486
# Acu valid: 0.5597382187843323
# tensor(0.7031)
# tensor(0.6641)
# tensor(0.7344)
# tensor(0.7344)
# tensor(0.7969)
# tensor(0.7578)
# tensor(0.7188)
# tensor(0.7500)
# tensor(0.7266)
# tensor(0.7656)
# tensor(0.7734)
# Acu Train: 0.7286162972450256
# Acu valid: 0.5590126514434814
# tensor(0.7344)
# tensor(0.7422)
# tensor(0.7500)
# tensor(0.7344)
# tensor(0.8047)
# tensor(0.7188)
# tensor(0.7422)
# tensor(0.7734)
# tensor(0.7422)
# tensor(0.7734)
# tensor(0.7891)
# Acu Train: 0.7682738304138184
# Acu valid: 0.552434504032135
# tensor(0.7578)
# tensor(0.7969)
# tensor(0.8203)
# tensor(0.8438)
# tensor(0.8203)
# tensor(0.8203)
# tensor(0.7578)
# tensor(0.8125)
# tensor(0.7734)
# tensor(0.7266)
# tensor(0.8359)
# Acu Train: 0.7988036870956421
# Acu valid: 0.5527088046073914
# tensor(0.8438)
# tensor(0.8438)
# tensor(0.7969)
# tensor(0.8672)
# tensor(0.7656)
# tensor(0.7969)
# tensor(0.8125)
# tensor(0.8281)
# tensor(0.8047)
# tensor(0.8359)
# tensor(0.8047)
# Acu Train: 0.8232771754264832
# Acu valid: 0.5417051315307617
# tensor(0.8828)
# tensor(0.8281)
# tensor(0.8672)
# tensor(0.8828)
# tensor(0.8281)
# tensor(0.8047)
# tensor(0.8359)
# tensor(0.8516)
# tensor(0.8203)
# tensor(0.7734)
# tensor(0.8438)
# Acu Train: 0.8424829840660095
# Acu valid: 0.5467796325683594
# tensor(0.8438)
# tensor(0.8984)
# tensor(0.8359)
# tensor(0.8125)
# tensor(0.8906)
# tensor(0.8438)
# tensor(0.8594)
# tensor(0.8359)
# tensor(0.8203)
# tensor(0.8125)
# tensor(0.8359)
# Acu Train: 0.8576626181602478
# Acu valid: 0.5401815176010132
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.8438)
# tensor(0.8359)
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.8906)
# tensor(0.8828)
# tensor(0.8672)
# tensor(0.8672)
# tensor(0.8828)
# Acu Train: 0.8702484965324402
# Acu valid: 0.5386912822723389
# tensor(0.9375)
# tensor(0.8516)
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.8594)
# tensor(0.8828)
# tensor(0.8750)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.8438)
# tensor(0.8828)
# Acu Train: 0.8805535435676575
# Acu valid: 0.542500913143158
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.8125)
# tensor(0.9062)
# tensor(0.9062)
# tensor(0.8828)
# tensor(0.8906)
# tensor(0.8750)
# tensor(0.8516)
# tensor(0.9141)
# tensor(0.7969)
# Acu Train: 0.8887771964073181
# Acu valid: 0.5359311103820801
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.9062)
# tensor(0.8516)
# tensor(0.8828)
# tensor(0.8828)
# tensor(0.8516)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.8359)
# Acu Train: 0.895600438117981
# Acu valid: 0.5449973344802856
# tensor(0.9297)
# tensor(0.9297)
# tensor(0.9531)
# tensor(0.9219)
# tensor(0.8984)
# tensor(0.9219)
# tensor(0.8750)
# tensor(0.9141)
# tensor(0.8672)
# tensor(0.9297)
# tensor(0.8672)
# Acu Train: 0.9008702039718628
# Acu valid: 0.5359936952590942
# tensor(0.9062)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.8516)
# tensor(0.8672)
# tensor(0.8828)
# tensor(0.9297)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.9062)
# Acu Train: 0.9052402973175049
# Acu valid: 0.5338662266731262
# tensor(0.9062)
# tensor(0.9453)
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.9062)
# tensor(0.9062)
# tensor(0.9453)
# tensor(0.8672)
# Acu Train: 0.9088349342346191
# Acu valid: 0.5399441123008728
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.8828)
# tensor(0.9141)
# Acu Train: 0.9115868210792542
# Acu valid: 0.5417028665542603
# tensor(0.8984)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.9375)
# tensor(0.8828)
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.8672)
# Acu Train: 0.9142178893089294
# Acu valid: 0.5314711928367615
# tensor(0.8750)
# tensor(0.9531)
# tensor(0.9453)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.9062)
# tensor(0.8906)
# Acu Train: 0.9146615266799927
# Acu valid: 0.5391883850097656
# tensor(0.9531)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9141)
# tensor(0.9219)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.9219)
# tensor(0.8906)
# Acu Train: 0.9168984293937683
# Acu valid: 0.5277655124664307
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.9531)
# tensor(0.8828)
# tensor(0.9531)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.9062)
# Acu Train: 0.9165365099906921
# Acu valid: 0.5339555740356445
# tensor(0.9141)
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.9375)
# tensor(0.9531)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.9375)
# Acu Train: 0.9165267944335938
# Acu valid: 0.5303843021392822
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9297)
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.8906)
# tensor(0.8281)
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.9531)
# Acu Train: 0.9149364829063416
# Acu valid: 0.5370259881019592
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.8594)
# tensor(0.9297)
# tensor(0.9688)
# tensor(0.9219)
# tensor(0.9453)
# tensor(0.8828)
# tensor(0.8750)
# Acu Train: 0.9159690141677856
# Acu valid: 0.5280518531799316
# tensor(0.9219)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.8750)
# tensor(0.8906)
# tensor(0.8438)
# tensor(0.9062)
# Acu Train: 0.9141115546226501
# Acu valid: 0.5339685678482056
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.9062)
# tensor(0.9453)
# tensor(0.8984)
# tensor(0.9141)
# tensor(0.8672)
# tensor(0.8750)
# tensor(0.8750)
# tensor(0.9688)
# tensor(0.9141)
# Acu Train: 0.8976074457168579
# Acu valid: 0.5304208397865295
# tensor(0.8984)
# tensor(0.9219)
# tensor(0.8594)
# tensor(0.7656)
# tensor(0.8984)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.8672)
# tensor(0.8828)
# tensor(0.8672)
# Acu Train: 0.9038962125778198
# Acu valid: 0.5314692854881287
# tensor(0.9531)
# tensor(0.8828)
# tensor(0.8281)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.9297)
# tensor(0.8594)
# tensor(0.9688)
# tensor(0.9062)
# Acu Train: 0.9030919671058655
# Acu valid: 0.5220124125480652
# tensor(0.8594)
# tensor(0.9297)
# tensor(0.8750)
# tensor(0.9219)
# tensor(0.8906)
# tensor(0.9453)
# tensor(0.8672)
# tensor(0.8828)
# tensor(0.8672)
# tensor(0.8750)
# tensor(0.9141)
# Acu Train: 0.9013587236404419
# Acu valid: 0.5326738357543945
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.9141)
# tensor(0.8984)
# tensor(0.8750)
# tensor(0.9844)
# tensor(0.9531)
# tensor(0.8672)
# tensor(0.8203)
# tensor(0.8906)
# tensor(0.9062)
# Acu Train: 0.896093487739563
# Acu valid: 0.523728609085083
# accu_fun is correct>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# tensor(0.0156)
# tensor(0.4375)
# tensor(0.4375)
# tensor(0.5000)
# tensor(0.5234)
# tensor(0.5547)
# tensor(0.5938)
# tensor(0.6094)
# tensor(0.5781)
# tensor(0.6562)
# Acu Train: 0.4941885471343994
# Acu valid: 0.5364288091659546
# tensor(0.5156)
# tensor(0.6016)
# tensor(0.6719)
# tensor(0.5547)
# tensor(0.6484)
# tensor(0.6875)
# tensor(0.7031)
# tensor(0.7031)
# tensor(0.5781)
# tensor(0.6172)
# Acu Train: 0.6452438235282898
# Acu valid: 0.5521997809410095
# tensor(0.7266)
# tensor(0.6328)
# tensor(0.7500)
# tensor(0.6953)
# tensor(0.7109)
# tensor(0.7656)
# tensor(0.6953)
# tensor(0.6953)
# tensor(0.6562)
# tensor(0.7891)
# Acu Train: 0.7174890041351318
# Acu valid: 0.5881233811378479
# tensor(0.7422)
# tensor(0.7500)
# tensor(0.7656)
# tensor(0.7734)
# tensor(0.7500)
# tensor(0.8047)
# tensor(0.8203)
# tensor(0.8203)
# tensor(0.7266)
# tensor(0.7500)
# Acu Train: 0.773014485836029
# Acu valid: 0.5659676194190979
# tensor(0.7891)
# tensor(0.8125)
# tensor(0.7734)
# tensor(0.8359)
# tensor(0.8438)
# tensor(0.7812)
# tensor(0.7734)
# tensor(0.8594)
# tensor(0.7891)
# tensor(0.8594)
# Acu Train: 0.8158996105194092
# Acu valid: 0.5625705122947693
# tensor(0.8359)
# tensor(0.8516)
# tensor(0.8750)
# tensor(0.8672)
# tensor(0.8125)
# tensor(0.8047)
# tensor(0.8047)
# tensor(0.8516)
# tensor(0.8516)
# tensor(0.8281)
# Acu Train: 0.8498030304908752
# Acu valid: 0.5750259160995483
# tensor(0.8828)
# tensor(0.8906)
# tensor(0.9219)
# tensor(0.8750)
# tensor(0.9141)
# tensor(0.8516)
# tensor(0.8984)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.8828)
# Acu Train: 0.8758776783943176
# Acu valid: 0.5465689897537231
# tensor(0.8984)
# tensor(0.8750)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.9375)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.8438)
# tensor(0.8906)
# tensor(0.8906)
# Acu Train: 0.8957861065864563
# Acu valid: 0.5588020086288452
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.8828)
# tensor(0.9609)
# tensor(0.9062)
# Acu Train: 0.9113876819610596
# Acu valid: 0.5558501482009888
# tensor(0.9453)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.8984)
# tensor(0.9453)
# tensor(0.9062)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9141)
# Acu Train: 0.9226986765861511
# Acu valid: 0.5720536708831787
# tensor(0.0078)
# tensor(0.3359)
# tensor(0.3203)
# tensor(0.3516)
# tensor(0.3047)
# tensor(0.4219)
# tensor(0.4922)
# tensor(0.3906)
# tensor(0.3906)
# tensor(0.4609)
# Acu Train: 0.35862982273101807
# Acu valid: 0.43345749378204346
# tensor(0.4922)
# tensor(0.3750)
# tensor(0.3672)
# tensor(0.4609)
# tensor(0.3516)
# tensor(0.4141)
# tensor(0.4609)
# tensor(0.4297)
# tensor(0.5000)
# tensor(0.3984)
# Acu Train: 0.44038280844688416
# Acu valid: 0.48439180850982666
# tensor(0.4297)
# tensor(0.4453)
# tensor(0.3750)
# tensor(0.4766)
# tensor(0.4531)
# tensor(0.4609)
# tensor(0.4922)
# tensor(0.4609)
# tensor(0.5078)
# tensor(0.5469)
# Acu Train: 0.4845554232597351
# Acu valid: 0.5104073286056519
# tensor(0.4766)
# tensor(0.5234)
# tensor(0.5391)
# tensor(0.4922)
# tensor(0.5078)
# tensor(0.4766)
# tensor(0.5312)
# tensor(0.5469)
# tensor(0.6016)
# tensor(0.5156)
# Acu Train: 0.5237310528755188
# Acu valid: 0.5269014835357666
# tensor(0.5391)
# tensor(0.5312)
# tensor(0.5156)
# tensor(0.4766)
# tensor(0.5312)
# tensor(0.5000)
# tensor(0.5547)
# tensor(0.5547)
# tensor(0.5781)
# tensor(0.5469)
# Acu Train: 0.5264772772789001
# Acu valid: 0.5417839884757996
# tensor(0.5625)
# tensor(0.4922)
# tensor(0.6562)
# tensor(0.6250)
# tensor(0.5547)
# tensor(0.5547)
# tensor(0.5547)
# tensor(0.4844)
# tensor(0.4766)
# tensor(0.5781)
# Acu Train: 0.559577465057373
# Acu valid: 0.5595380663871765
# tensor(0.6328)
# tensor(0.6094)
# tensor(0.6484)
# tensor(0.5781)
# tensor(0.6328)
# tensor(0.5625)
# tensor(0.6016)
# tensor(0.6719)
# tensor(0.6250)
# tensor(0.6719)
# Acu Train: 0.5813625454902649
# Acu valid: 0.5726235508918762
# tensor(0.5859)
# tensor(0.6094)
# tensor(0.5156)
# tensor(0.6484)
# tensor(0.5391)
# tensor(0.5469)
# tensor(0.5312)
# tensor(0.5781)
# tensor(0.6094)
# tensor(0.6328)
# Acu Train: 0.5951322913169861
# Acu valid: 0.5772862434387207
# tensor(0.6016)
# tensor(0.5938)
# tensor(0.5938)
# tensor(0.6094)
# tensor(0.5938)
# tensor(0.5938)
# tensor(0.6250)
# tensor(0.6641)
# tensor(0.6328)
# tensor(0.5625)
# Acu Train: 0.6117226481437683
# Acu valid: 0.585280179977417
# tensor(0.5156)
# tensor(0.5859)
# tensor(0.6094)
# tensor(0.6406)
# tensor(0.6484)
# tensor(0.6562)
# tensor(0.6016)
# tensor(0.5781)
# tensor(0.6797)
# tensor(0.5391)
# Acu Train: 0.6217063665390015
# Acu valid: 0.585482656955719
# tensor(0.7031)
# tensor(0.6328)
# tensor(0.6250)
# tensor(0.6328)
# tensor(0.6562)
# tensor(0.7031)
# tensor(0.4297)
# tensor(0.6406)
# tensor(0.7422)
# tensor(0.6641)
# Acu Train: 0.6313650012016296
# Acu valid: 0.6022319197654724
# tensor(0.6406)
# tensor(0.6562)
# tensor(0.6875)
# tensor(0.6641)
# tensor(0.6484)
# tensor(0.6641)
# tensor(0.6406)
# tensor(0.6641)
# tensor(0.6016)
# tensor(0.6406)
# Acu Train: 0.645437479019165
# Acu valid: 0.6025984287261963
# tensor(0.6328)
# tensor(0.5859)
# tensor(0.6172)
# tensor(0.6484)
# tensor(0.6250)
# tensor(0.5547)
# tensor(0.6250)
# tensor(0.5781)
# tensor(0.6562)
# tensor(0.6172)
# Acu Train: 0.6319725513458252
# Acu valid: 0.5942236185073853
# tensor(0.6094)
# tensor(0.5938)
# tensor(0.6875)
# tensor(0.6484)
# tensor(0.7109)
# tensor(0.5938)
# tensor(0.5938)
# tensor(0.6328)
# tensor(0.6953)
# tensor(0.7344)
# Acu Train: 0.6513580083847046
# Acu valid: 0.6041569113731384
# tensor(0.7266)
# tensor(0.6719)
# tensor(0.6797)
# tensor(0.6328)
# tensor(0.6562)
# tensor(0.6953)
# tensor(0.6328)
# tensor(0.7188)
# tensor(0.6094)
# tensor(0.6719)
# Acu Train: 0.6652857661247253
# Acu valid: 0.6098172068595886
# tensor(0.6797)
# tensor(0.7578)
# tensor(0.7344)
# tensor(0.6953)
# tensor(0.6797)
# tensor(0.6328)
# tensor(0.6484)
# tensor(0.6797)
# tensor(0.6484)
# tensor(0.6094)
# Acu Train: 0.6694713234901428
# Acu valid: 0.6094836592674255
# tensor(0.6719)
# tensor(0.5938)
# tensor(0.7812)
# tensor(0.6328)
# tensor(0.6562)
# tensor(0.5781)
# tensor(0.7344)
# tensor(0.6094)
# tensor(0.7344)
# tensor(0.7188)
# Acu Train: 0.6790422201156616
# Acu valid: 0.6148394346237183
# tensor(0.6641)
# tensor(0.7266)
# tensor(0.6797)
# tensor(0.7266)
# tensor(0.6094)
# tensor(0.6172)
# tensor(0.7344)
# tensor(0.6797)
# tensor(0.6797)
# tensor(0.7109)
# Acu Train: 0.6852604150772095
# Acu valid: 0.6078149080276489
# tensor(0.7109)
# tensor(0.7188)
# tensor(0.7031)
# tensor(0.6641)
# tensor(0.7734)
# tensor(0.7109)
# tensor(0.6484)
# tensor(0.7109)
# tensor(0.7031)
# tensor(0.6875)
# Acu Train: 0.6901891231536865
# Acu valid: 0.6084315180778503
# tensor(0.6406)
# tensor(0.7422)
# tensor(0.7422)
# tensor(0.6875)
# tensor(0.6328)
# tensor(0.6641)
# tensor(0.6953)
# tensor(0.6953)
# tensor(0.7422)
# tensor(0.6484)
# Acu Train: 0.6933430433273315
# Acu valid: 0.6139078140258789
# tensor(0.6797)
# tensor(0.7344)
# tensor(0.7188)
# tensor(0.7578)
# tensor(0.6328)
# tensor(0.7266)
# tensor(0.6719)
# tensor(0.7578)
# tensor(0.6797)
# tensor(0.7266)
# Acu Train: 0.6953604221343994
# Acu valid: 0.6139057278633118
# tensor(0.6641)
# tensor(0.7188)
# tensor(0.7266)
# tensor(0.7188)
# tensor(0.6641)
# tensor(0.6562)
# tensor(0.7188)
# tensor(0.7344)
# tensor(0.7188)
# tensor(0.7109)
# Acu Train: 0.698133111000061
# Acu valid: 0.6149017214775085
# tensor(0.7422)
# tensor(0.7266)
# tensor(0.7969)
# tensor(0.7344)
# tensor(0.7734)
# tensor(0.7500)
# tensor(0.7891)
# tensor(0.6641)
# tensor(0.7500)
# tensor(0.7188)
# Acu Train: 0.7052229046821594
# Acu valid: 0.6055047512054443
# tensor(0.7656)
# tensor(0.8047)
# tensor(0.6797)
# tensor(0.6875)
# tensor(0.7188)
# tensor(0.6484)
# tensor(0.6562)
# tensor(0.7266)
# tensor(0.7031)
# tensor(0.6328)
# Acu Train: 0.7068344950675964
# Acu valid: 0.6221693754196167
# tensor(0.7188)
# tensor(0.7422)
# tensor(0.7422)
# tensor(0.7266)
# tensor(0.7188)
# tensor(0.6875)
# tensor(0.7109)
# tensor(0.7656)
# tensor(0.7188)
# tensor(0.7578)
# Acu Train: 0.7178172469139099
# Acu valid: 0.6177640557289124
# tensor(0.6641)
# tensor(0.6797)
# tensor(0.7422)
# tensor(0.7109)
# tensor(0.6719)
# tensor(0.7031)
# tensor(0.7656)
# tensor(0.7266)
# tensor(0.7578)
# tensor(0.7266)
# Acu Train: 0.7231934666633606
# Acu valid: 0.6074504852294922
# tensor(0.6328)
# tensor(0.7812)
# tensor(0.6719)
# tensor(0.6875)
# tensor(0.7188)
# tensor(0.6484)
# tensor(0.6641)
# tensor(0.7891)
# tensor(0.7422)
# tensor(0.7188)
# Acu Train: 0.7150241732597351
# Acu valid: 0.6167961955070496
# tensor(0.6328)
# tensor(0.6719)
# tensor(0.7188)
# tensor(0.7422)
# tensor(0.6875)
# tensor(0.7500)
# tensor(0.7188)
# tensor(0.7188)
# tensor(0.7109)
# tensor(0.7109)
# Acu Train: 0.717921257019043
# Acu valid: 0.6207711696624756
# tensor(0.7422)
# tensor(0.7188)
# tensor(0.7578)
# tensor(0.7109)
# tensor(0.7266)
# tensor(0.6797)
# tensor(0.7266)
# tensor(0.7109)
# tensor(0.7891)
# tensor(0.7031)
# Acu Train: 0.7264055013656616
# Acu valid: 0.617240846157074
# tensor(0.7344)
# tensor(0.7891)
# tensor(0.7812)
# tensor(0.7266)
# tensor(0.7734)
# tensor(0.7266)
# tensor(0.7812)
# tensor(0.6172)
# tensor(0.7500)
# tensor(0.7812)
# Acu Train: 0.7279050350189209
# Acu valid: 0.6229820847511292
# tensor(0.7266)
# tensor(0.7266)
# tensor(0.6719)
# tensor(0.7266)
# tensor(0.7188)
# tensor(0.7031)
# tensor(0.7656)
# tensor(0.8203)
# tensor(0.7812)
# tensor(0.7031)
# Acu Train: 0.7257000803947449
# Acu valid: 0.6201664209365845
# tensor(0.7188)
# tensor(0.7500)
# tensor(0.7578)
# tensor(0.7500)
# tensor(0.6484)
# tensor(0.7031)
# tensor(0.7109)
# tensor(0.7578)
# tensor(0.6875)
# tensor(0.7734)
# Acu Train: 0.7202128171920776
# Acu valid: 0.618336021900177
# tensor(0.7109)
# tensor(0.7422)
# tensor(0.7969)
# tensor(0.6719)
# tensor(0.7578)
# tensor(0.6094)
# tensor(0.6562)
# tensor(0.6250)
# tensor(0.6719)
# tensor(0.7969)
# Acu Train: 0.7221883535385132
# Acu valid: 0.6156609058380127
# tensor(0.6797)
# tensor(0.7500)
# tensor(0.7344)
# tensor(0.7109)
# tensor(0.7656)
# tensor(0.7891)
# tensor(0.7344)
# tensor(0.7344)
# tensor(0.7188)
# tensor(0.7656)
# Acu Train: 0.7282434701919556
# Acu valid: 0.6169552803039551
# tensor(0.7109)
# tensor(0.7266)
# tensor(0.7109)
# tensor(0.7812)
# tensor(0.8047)
# tensor(0.7031)
# tensor(0.7578)
# tensor(0.7344)
# tensor(0.8047)
# tensor(0.7266)
# Acu Train: 0.7327633500099182
# Acu valid: 0.6192600131034851
# tensor(0.7812)
# tensor(0.7578)
# tensor(0.7031)
# tensor(0.7500)
# tensor(0.6719)
# tensor(0.6875)
# tensor(0.6719)
# tensor(0.6484)
# tensor(0.6562)
# tensor(0.7109)
# Acu Train: 0.7159701585769653
# Acu valid: 0.5949373841285706
# tensor(0.6484)
# tensor(0.6719)
# tensor(0.7188)
# tensor(0.6562)
# tensor(0.7578)
# tensor(0.6953)
# tensor(0.6094)
# tensor(0.7578)
# tensor(0.7344)
# tensor(0.7344)
# Acu Train: 0.6962319612503052
# Acu valid: 0.6181265711784363
# tensor(0.7188)
# tensor(0.7422)
# tensor(0.6797)
# tensor(0.6562)
# tensor(0.7266)
# tensor(0.6797)
# tensor(0.7266)
# tensor(0.7500)
# tensor(0.6484)
# tensor(0.6797)
# Acu Train: 0.7268917560577393
# Acu valid: 0.6148042678833008
# tensor(0.7734)
# tensor(0.7422)
# tensor(0.7812)
# tensor(0.7891)
# tensor(0.7188)
# tensor(0.7344)
# tensor(0.7969)
# tensor(0.7422)
# tensor(0.7109)
# tensor(0.7031)
# Acu Train: 0.7346798181533813
# Acu valid: 0.6250854134559631
# tensor(0.7734)
# tensor(0.7656)
# tensor(0.6562)
# tensor(0.7578)
# tensor(0.7500)
# tensor(0.7188)
# tensor(0.7656)
# tensor(0.7734)
# tensor(0.7812)
# tensor(0.7656)
# Acu Train: 0.7524577379226685
# Acu valid: 0.619477391242981
# tensor(0.7266)
# tensor(0.7344)
# tensor(0.7578)
# tensor(0.7500)
# tensor(0.7500)
# tensor(0.7734)
# tensor(0.8594)
# tensor(0.7344)
# tensor(0.7656)
# tensor(0.7656)
# Acu Train: 0.7535097002983093
# Acu valid: 0.6137955188751221
# tensor(0.7500)
# tensor(0.7188)
# tensor(0.8125)
# tensor(0.7812)
# tensor(0.7422)
# tensor(0.7344)
# tensor(0.6953)
# tensor(0.7656)
# tensor(0.7734)
# tensor(0.7812)
# Acu Train: 0.7407430410385132
# Acu valid: 0.6213560104370117
# tensor(0.8125)
# tensor(0.7969)
# tensor(0.7891)
# tensor(0.7969)
# tensor(0.6953)
# tensor(0.7109)
# tensor(0.7812)
# tensor(0.8047)
# tensor(0.7969)
# tensor(0.8281)
# Acu Train: 0.7488532066345215
# Acu valid: 0.6131439805030823
# tensor(0.7656)
# tensor(0.7422)
# tensor(0.7344)
# tensor(0.7188)
# tensor(0.7969)
# tensor(0.8047)
# tensor(0.7031)
# tensor(0.7969)
# tensor(0.7578)
# tensor(0.6172)
# Acu Train: 0.7538858652114868
# Acu valid: 0.5990302562713623
# tensor(0.6641)
# tensor(0.7266)
# tensor(0.8125)
# tensor(0.7266)
# tensor(0.7656)
# tensor(0.7266)
# tensor(0.7344)
# tensor(0.7500)
# tensor(0.7266)
# tensor(0.7734)
# Acu Train: 0.7580214738845825
# Acu valid: 0.6160659790039062
# tensor(0.7500)
# tensor(0.7344)
# tensor(0.7891)
# tensor(0.7344)
# tensor(0.7812)
# tensor(0.7812)
# tensor(0.8047)
# tensor(0.7578)
# tensor(0.7891)
# tensor(0.7188)
# Acu Train: 0.7566707730293274
# Acu valid: 0.6248570084571838
# tensor(0.6875)
# tensor(0.7578)
# tensor(0.8047)
# tensor(0.7188)
# tensor(0.6953)
# tensor(0.7969)
# tensor(0.7656)
# tensor(0.7422)
# tensor(0.8203)
# tensor(0.7656)
# Acu Train: 0.7625821828842163
# Acu valid: 0.6121166348457336
# tensor(0.7578)
# tensor(0.7109)
# tensor(0.7578)
# tensor(0.7031)
# tensor(0.7109)
# tensor(0.7891)
# tensor(0.7031)
# tensor(0.7656)
# tensor(0.7734)
# tensor(0.7656)
# Acu Train: 0.7595036625862122
# Acu valid: 0.6176317930221558
# tensor(0.7969)
# tensor(0.7578)
# tensor(0.7422)
# tensor(0.7109)
# tensor(0.7734)
# tensor(0.7500)
# tensor(0.7188)
# tensor(0.8281)
# tensor(0.7578)
# tensor(0.5938)
# Acu Train: 0.7593436241149902
# Acu valid: 0.6122748255729675
# tensor(0.7266)
# tensor(0.8125)
# tensor(0.7734)
# tensor(0.7422)
# tensor(0.7891)
# tensor(0.7734)
# tensor(0.7969)
# tensor(0.7031)
# tensor(0.7734)
# tensor(0.7109)
# Acu Train: 0.767597496509552
# Acu valid: 0.6218947768211365
# tensor(0.)
# tensor(0.3594)
# tensor(0.4375)
# tensor(0.4609)
# tensor(0.4609)
# tensor(0.4453)
# tensor(0.4922)
# tensor(0.5391)
# tensor(0.5391)
# tensor(0.5156)
# Acu Train: 0.45394763350486755
# Acu valid: 0.5171074867248535
# tensor(0.5547)
# tensor(0.4844)
# tensor(0.5859)
# tensor(0.5469)
# tensor(0.6094)
# tensor(0.6328)
# tensor(0.6328)
# tensor(0.5625)
# tensor(0.6641)
# tensor(0.7031)
# Acu Train: 0.6133995056152344
# Acu valid: 0.55638188123703
# tensor(0.6641)
# tensor(0.6328)
# tensor(0.6875)
# tensor(0.7266)
# tensor(0.6875)
# tensor(0.7344)
# tensor(0.7734)
# tensor(0.7266)
# tensor(0.7266)
# tensor(0.7344)
# Acu Train: 0.68935626745224
# Acu valid: 0.5540146827697754
# tensor(0.7578)
# tensor(0.7344)
# tensor(0.7344)
# tensor(0.7578)
# tensor(0.7578)
# tensor(0.7578)
# tensor(0.7344)
# tensor(0.7812)
# tensor(0.7578)
# tensor(0.7812)
# Acu Train: 0.7415351271629333
# Acu valid: 0.5622144341468811
# tensor(0.7031)
# tensor(0.7734)
# tensor(0.8281)
# tensor(0.7500)
# tensor(0.8594)
# tensor(0.7891)
# tensor(0.7891)
# tensor(0.7422)
# tensor(0.7734)
# tensor(0.8125)
# Acu Train: 0.7817199230194092
# Acu valid: 0.5635624527931213
# tensor(0.7109)
# tensor(0.8281)
# tensor(0.8281)
# tensor(0.7734)
# tensor(0.8281)
# tensor(0.7656)
# tensor(0.8047)
# tensor(0.7969)
# tensor(0.8125)
# tensor(0.7891)
# Acu Train: 0.8120249509811401
# Acu valid: 0.5555621981620789
# tensor(0.8203)
# tensor(0.8047)
# tensor(0.8438)
# tensor(0.7891)
# tensor(0.8359)
# tensor(0.7734)
# tensor(0.8594)
# tensor(0.8438)
# tensor(0.8438)
# tensor(0.8516)
# Acu Train: 0.8355919122695923
# Acu valid: 0.5553914904594421
# tensor(0.8438)
# tensor(0.8281)
# tensor(0.8438)
# tensor(0.8828)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.7969)
# tensor(0.8750)
# tensor(0.8438)
# tensor(0.8594)
# Acu Train: 0.8546358942985535
# Acu valid: 0.5527832508087158
# tensor(0.9219)
# tensor(0.8359)
# tensor(0.8828)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.8203)
# tensor(0.8672)
# tensor(0.8750)
# tensor(0.8438)
# Acu Train: 0.8686441779136658
# Acu valid: 0.5596474409103394
# tensor(0.8906)
# tensor(0.9453)
# tensor(0.8750)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.8516)
# tensor(0.8516)
# tensor(0.9453)
# tensor(0.8672)
# tensor(0.8750)
# Acu Train: 0.8810102343559265
# Acu valid: 0.5556375980377197
# tensor(0.8516)
# tensor(0.8984)
# tensor(0.8594)
# tensor(0.9297)
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.8828)
# tensor(0.8516)
# tensor(0.9219)
# Acu Train: 0.8893446922302246
# Acu valid: 0.5491610169410706
# tensor(0.8828)
# tensor(0.8047)
# tensor(0.8906)
# tensor(0.8750)
# tensor(0.8359)
# tensor(0.9141)
# tensor(0.8594)
# tensor(0.8438)
# tensor(0.9219)
# tensor(0.8984)
# Acu Train: 0.8963895440101624
# Acu valid: 0.5495269298553467
# tensor(0.9219)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.8750)
# tensor(0.9375)
# tensor(0.8672)
# tensor(0.8906)
# tensor(0.8594)
# Acu Train: 0.9026638269424438
# Acu valid: 0.5519044995307922
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.9219)
# tensor(0.8984)
# tensor(0.8750)
# tensor(0.8672)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.9453)
# tensor(0.9141)
# Acu Train: 0.9074905514717102
# Acu valid: 0.5483846664428711
# tensor(0.9062)
# tensor(0.9453)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.8828)
# Acu Train: 0.9115446209907532
# Acu valid: 0.5492305755615234
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.8984)
# tensor(0.9297)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.9219)
# tensor(0.9141)
# Acu Train: 0.914344847202301
# Acu valid: 0.5464978218078613
# tensor(0.8984)
# tensor(0.9844)
# tensor(0.9297)
# tensor(0.9531)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.9453)
# tensor(0.9375)
# tensor(0.9453)
# Acu Train: 0.9163917899131775
# Acu valid: 0.5501419305801392
# tensor(0.9453)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.8984)
# tensor(0.9531)
# tensor(0.8984)
# tensor(0.8984)
# tensor(0.9609)
# tensor(0.9141)
# Acu Train: 0.9183551073074341
# Acu valid: 0.5476146936416626
# tensor(0.9531)
# tensor(0.8984)
# tensor(0.9453)
# tensor(0.9141)
# tensor(0.9219)
# tensor(0.8984)
# tensor(0.9609)
# tensor(0.8906)
# tensor(0.8672)
# tensor(0.9062)
# Acu Train: 0.9197832345962524
# Acu valid: 0.5463123321533203
# tensor(0.9609)
# tensor(0.9297)
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.9062)
# Acu Train: 0.9181817770004272
# Acu valid: 0.5468561053276062
# tensor(0.9922)
# tensor(0.9297)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.9531)
# tensor(0.9219)
# tensor(0.8984)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9219)
# Acu Train: 0.9216242432594299
# Acu valid: 0.5452587008476257
# tensor(0.9531)
# tensor(0.9375)
# tensor(0.8984)
# tensor(0.9297)
# tensor(0.9375)
# tensor(0.8828)
# tensor(0.9219)
# tensor(0.8750)
# tensor(0.9297)
# tensor(0.9531)
# Acu Train: 0.9191746711730957
# Acu valid: 0.5432991981506348
# tensor(0.9219)
# tensor(0.9297)
# tensor(0.9297)
# tensor(0.9609)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9531)
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.9219)
# Acu Train: 0.920069694519043
# Acu valid: 0.5461987853050232
# tensor(0.9609)
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.8672)
# tensor(0.9219)
# tensor(0.8828)
# tensor(0.8984)
# tensor(0.9531)
# Acu Train: 0.9192062616348267
# Acu valid: 0.5480303764343262
# tensor(0.9375)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.8438)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.8984)
# tensor(0.9375)
# Acu Train: 0.9185711741447449
# Acu valid: 0.5444972515106201
# tensor(0.9688)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.9297)
# tensor(0.8672)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.8359)
# tensor(0.9219)
# tensor(0.9219)
# Acu Train: 0.9016832113265991
# Acu valid: 0.5443427562713623
# tensor(0.9609)
# tensor(0.8750)
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.9297)
# tensor(0.8672)
# tensor(0.8984)
# tensor(0.8828)
# tensor(0.9375)
# tensor(0.8906)
# Acu Train: 0.9108086228370667
# Acu valid: 0.5364652872085571
# tensor(0.8750)
# tensor(0.8906)
# tensor(0.9219)
# tensor(0.9609)
# tensor(0.9062)
# tensor(0.8516)
# tensor(0.8906)
# tensor(0.8906)
# tensor(0.8750)
# tensor(0.9141)
# Acu Train: 0.8794995546340942
# Acu valid: 0.5451909303665161
# tensor(0.9453)
# tensor(0.8594)
# tensor(0.3828)
# tensor(0.6016)
# tensor(0.6094)
# tensor(0.5312)
# tensor(0.5469)
# tensor(0.5469)
# tensor(0.4609)
# tensor(0.5938)
# Acu Train: 0.5666998028755188
# Acu valid: 0.5261437296867371
# tensor(0.5781)
# tensor(0.6094)
# tensor(0.6328)
# tensor(0.6562)
# tensor(0.6172)
# tensor(0.5469)
# tensor(0.6484)
# tensor(0.6250)
# tensor(0.6250)
# tensor(0.6641)
# Acu Train: 0.6365719437599182
# Acu valid: 0.5617993474006653
# accu_fun is correct>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# tensor(0.0312)
# tensor(0.3281)
# tensor(0.3984)
# tensor(0.4609)
# tensor(0.3672)
# tensor(0.5156)
# tensor(0.5703)
# tensor(0.5781)
# tensor(0.6250)
# tensor(0.6250)
# Acu Train: 0.46080854535102844
# Acu valid: 0.5162695050239563
# tensor(0.6094)
# tensor(0.5781)
# tensor(0.5312)
# tensor(0.5703)
# tensor(0.6562)
# tensor(0.6875)
# tensor(0.7266)
# tensor(0.7266)
# tensor(0.7266)
# tensor(0.7422)
# Acu Train: 0.6362621784210205
# Acu valid: 0.558856189250946
# tensor(0.6406)
# tensor(0.7031)
# tensor(0.7344)
# tensor(0.6797)
# tensor(0.6797)
# tensor(0.7109)
# tensor(0.7422)
# tensor(0.8047)
# tensor(0.6953)
# tensor(0.7656)
# Acu Train: 0.7220643758773804
# Acu valid: 0.5609741806983948
# tensor(0.8125)
# tensor(0.8281)
# tensor(0.7109)
# tensor(0.7344)
# tensor(0.6797)
# tensor(0.8281)
# tensor(0.8203)
# tensor(0.8438)
# tensor(0.7812)
# tensor(0.7891)
# Acu Train: 0.7860201001167297
# Acu valid: 0.5522263646125793
# tensor(0.8594)
# tensor(0.8203)
# tensor(0.8281)
# tensor(0.8203)
# tensor(0.8203)
# tensor(0.7969)
# tensor(0.8750)
# tensor(0.7812)
# tensor(0.8828)
# tensor(0.8906)
# Acu Train: 0.8328290581703186
# Acu valid: 0.5449259281158447
# tensor(0.8828)
# tensor(0.8359)
# tensor(0.8359)
# tensor(0.8984)
# tensor(0.8672)
# tensor(0.8438)
# tensor(0.8438)
# tensor(0.8750)
# tensor(0.8984)
# tensor(0.9062)
# Acu Train: 0.8673381805419922
# Acu valid: 0.5528143644332886
# tensor(0.9062)
# tensor(0.8594)
# tensor(0.8438)
# tensor(0.8750)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.8594)
# tensor(0.8984)
# tensor(0.8828)
# tensor(0.9375)
# Acu Train: 0.8915174007415771
# Acu valid: 0.5063025951385498
# tensor(0.9219)
# tensor(0.8984)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.8906)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.9062)
# Acu Train: 0.9093535542488098
# Acu valid: 0.5309797525405884
# tensor(0.9375)
# tensor(0.8906)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.9297)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.9453)
# Acu Train: 0.9226848483085632
# Acu valid: 0.5180482864379883
# tensor(0.9062)
# tensor(0.9609)
# tensor(0.9375)
# tensor(0.8594)
# tensor(0.9375)
# tensor(0.9531)
# tensor(0.9297)
# tensor(0.8750)
# tensor(0.9219)
# tensor(0.9219)
# Acu Train: 0.9325699806213379
# Acu valid: 0.5295197367668152
# tensor(0.0156)
# tensor(0.2578)
# tensor(0.3750)
# tensor(0.2891)
# tensor(0.2891)
# tensor(0.3906)
# tensor(0.3672)
# tensor(0.3281)
# tensor(0.2734)
# tensor(0.2969)
# Acu Train: 0.3041992783546448
# Acu valid: 0.3649338185787201
# tensor(0.3984)
# tensor(0.4453)
# tensor(0.3047)
# tensor(0.3594)
# tensor(0.3672)
# tensor(0.4219)
# tensor(0.3516)
# tensor(0.4609)
# tensor(0.3984)
# tensor(0.4375)
# Acu Train: 0.38864991068840027
# Acu valid: 0.4213143289089203
# tensor(0.4844)
# tensor(0.4609)
# tensor(0.4922)
# tensor(0.4375)
# tensor(0.4531)
# tensor(0.4219)
# tensor(0.4297)
# tensor(0.4375)
# tensor(0.3750)
# tensor(0.4375)
# Acu Train: 0.4201411306858063
# Acu valid: 0.43946346640586853
# tensor(0.4688)
# tensor(0.3828)
# tensor(0.4219)
# tensor(0.4062)
# tensor(0.4766)
# tensor(0.4766)
# tensor(0.5234)
# tensor(0.4766)
# tensor(0.4297)
# tensor(0.4219)
# Acu Train: 0.4543604254722595
# Acu valid: 0.4327557682991028
# tensor(0.5078)
# tensor(0.4844)
# tensor(0.4844)
# tensor(0.3906)
# tensor(0.4531)
# tensor(0.4922)
# tensor(0.4922)
# tensor(0.4609)
# tensor(0.5312)
# tensor(0.5234)
# Acu Train: 0.48003116250038147
# Acu valid: 0.49670007824897766
# tensor(0.5078)
# tensor(0.5000)
# tensor(0.5312)
# tensor(0.4375)
# tensor(0.4297)
# tensor(0.5156)
# tensor(0.5859)
# tensor(0.4688)
# tensor(0.5000)
# tensor(0.5234)
# Acu Train: 0.49851855635643005
# Acu valid: 0.5029606819152832
# tensor(0.5781)
# tensor(0.5156)
# tensor(0.5156)
# tensor(0.6094)
# tensor(0.5469)
# tensor(0.5547)
# tensor(0.4531)
# tensor(0.5625)
# tensor(0.6016)
# tensor(0.4766)
# Acu Train: 0.5166046619415283
# Acu valid: 0.511802077293396
# tensor(0.5469)
# tensor(0.4688)
# tensor(0.6094)
# tensor(0.4453)
# tensor(0.5859)
# tensor(0.4453)
# tensor(0.5156)
# tensor(0.5625)
# tensor(0.5625)
# tensor(0.5156)
# Acu Train: 0.5219756364822388
# Acu valid: 0.5284194946289062
# tensor(0.5469)
# tensor(0.5000)
# tensor(0.5234)
# tensor(0.4766)
# tensor(0.4766)
# tensor(0.5078)
# tensor(0.5938)
# tensor(0.4922)
# tensor(0.6016)
# tensor(0.4844)
# Acu Train: 0.5168508887290955
# Acu valid: 0.534675121307373
# tensor(0.5703)
# tensor(0.4688)
# tensor(0.5469)
# tensor(0.4922)
# tensor(0.6328)
# tensor(0.5469)
# tensor(0.5469)
# tensor(0.5000)
# tensor(0.5625)
# tensor(0.5156)
# Acu Train: 0.5304996371269226
# Acu valid: 0.5406519174575806
# tensor(0.4922)
# tensor(0.5469)
# tensor(0.5234)
# tensor(0.5469)
# tensor(0.5547)
# tensor(0.5703)
# tensor(0.5000)
# tensor(0.5234)
# tensor(0.6016)
# tensor(0.4141)
# Acu Train: 0.5519195795059204
# Acu valid: 0.5235636234283447
# tensor(0.5078)
# tensor(0.5078)
# tensor(0.5703)
# tensor(0.5547)
# tensor(0.5938)
# tensor(0.5703)
# tensor(0.5078)
# tensor(0.5938)
# tensor(0.5859)
# tensor(0.4531)
# Acu Train: 0.5612910389900208
# Acu valid: 0.5407484769821167
# tensor(0.5312)
# tensor(0.5391)
# tensor(0.6016)
# tensor(0.5234)
# tensor(0.5781)
# tensor(0.5703)
# tensor(0.4297)
# tensor(0.4766)
# tensor(0.5859)
# tensor(0.6016)
# Acu Train: 0.530034065246582
# Acu valid: 0.5339124798774719
# tensor(0.5469)
# tensor(0.5391)
# tensor(0.5703)
# tensor(0.5156)
# tensor(0.3828)
# tensor(0.5547)
# tensor(0.5156)
# tensor(0.5078)
# tensor(0.5000)
# tensor(0.5391)
# Acu Train: 0.5513747930526733
# Acu valid: 0.5502001643180847
# tensor(0.5469)
# tensor(0.6094)
# tensor(0.5938)
# tensor(0.5234)
# tensor(0.5938)
# tensor(0.6484)
# tensor(0.5781)
# tensor(0.6406)
# tensor(0.6172)
# tensor(0.5078)
# Acu Train: 0.5742694139480591
# Acu valid: 0.5469109416007996
# tensor(0.5938)
# tensor(0.5312)
# tensor(0.5469)
# tensor(0.4922)
# tensor(0.5938)
# tensor(0.6641)
# tensor(0.6016)
# tensor(0.5078)
# tensor(0.5781)
# tensor(0.4766)
# Acu Train: 0.5712553858757019
# Acu valid: 0.5533345937728882
# tensor(0.6797)
# tensor(0.6172)
# tensor(0.5703)
# tensor(0.5781)
# tensor(0.6016)
# tensor(0.5703)
# tensor(0.5781)
# tensor(0.6719)
# tensor(0.5625)
# tensor(0.5625)
# Acu Train: 0.5828781723976135
# Acu valid: 0.5611042380332947
# tensor(0.7031)
# tensor(0.6328)
# tensor(0.6562)
# tensor(0.5781)
# tensor(0.6328)
# tensor(0.5781)
# tensor(0.6094)
# tensor(0.5391)
# tensor(0.6172)
# tensor(0.6328)
# Acu Train: 0.5877088308334351
# Acu valid: 0.5546776056289673
# tensor(0.6094)
# tensor(0.5859)
# tensor(0.6328)
# tensor(0.5703)
# tensor(0.5859)
# tensor(0.6250)
# tensor(0.6094)
# tensor(0.5625)
# tensor(0.6328)
# tensor(0.6484)
# Acu Train: 0.6000727415084839
# Acu valid: 0.5614007711410522
# tensor(0.6172)
# tensor(0.5781)
# tensor(0.6719)
# tensor(0.6094)
# tensor(0.6094)
# tensor(0.6016)
# tensor(0.6719)
# tensor(0.6094)
# tensor(0.6562)
# tensor(0.5547)
# Acu Train: 0.611385703086853
# Acu valid: 0.5595490336418152
# tensor(0.5859)
# tensor(0.6641)
# tensor(0.6406)
# tensor(0.5078)
# tensor(0.6172)
# tensor(0.6953)
# tensor(0.6797)
# tensor(0.6641)
# tensor(0.5938)
# tensor(0.6719)
# Acu Train: 0.6147260665893555
# Acu valid: 0.5556665062904358
# tensor(0.6641)
# tensor(0.6406)
# tensor(0.6328)
# tensor(0.4766)
# tensor(0.6406)
# tensor(0.6719)
# tensor(0.6016)
# tensor(0.6406)
# tensor(0.6328)
# tensor(0.6016)
# Acu Train: 0.6115418672561646
# Acu valid: 0.5713897347450256
# tensor(0.5625)
# tensor(0.6641)
# tensor(0.6172)
# tensor(0.5391)
# tensor(0.6406)
# tensor(0.6641)
# tensor(0.6094)
# tensor(0.6562)
# tensor(0.5469)
# tensor(0.6094)
# Acu Train: 0.6261521577835083
# Acu valid: 0.569955050945282
# tensor(0.6328)
# tensor(0.7266)
# tensor(0.6406)
# tensor(0.6094)
# tensor(0.7031)
# tensor(0.6328)
# tensor(0.6484)
# tensor(0.6562)
# tensor(0.6172)
# tensor(0.6094)
# Acu Train: 0.6293491125106812
# Acu valid: 0.5725709199905396
# tensor(0.6953)
# tensor(0.5703)
# tensor(0.5703)
# tensor(0.5859)
# tensor(0.5547)
# tensor(0.6328)
# tensor(0.5703)
# tensor(0.6641)
# tensor(0.6641)
# tensor(0.5547)
# Acu Train: 0.6284133791923523
# Acu valid: 0.5637595653533936
# tensor(0.6172)
# tensor(0.7500)
# tensor(0.6797)
# tensor(0.6797)
# tensor(0.7266)
# tensor(0.6172)
# tensor(0.6875)
# tensor(0.6484)
# tensor(0.6797)
# tensor(0.6562)
# Acu Train: 0.6467738747596741
# Acu valid: 0.5735252499580383
# tensor(0.6484)
# tensor(0.6719)
# tensor(0.5703)
# tensor(0.6250)
# tensor(0.7500)
# tensor(0.7109)
# tensor(0.6562)
# tensor(0.6484)
# tensor(0.6719)
# tensor(0.6719)
# Acu Train: 0.6499469876289368
# Acu valid: 0.5730606913566589
# tensor(0.6094)
# tensor(0.6250)
# tensor(0.6953)
# tensor(0.7578)
# tensor(0.6875)
# tensor(0.7266)
# tensor(0.6641)
# tensor(0.6250)
# tensor(0.7344)
# tensor(0.6172)
# Acu Train: 0.6600735187530518
# Acu valid: 0.5749726891517639
# tensor(0.7109)
# tensor(0.6797)
# tensor(0.5938)
# tensor(0.6484)
# tensor(0.7578)
# tensor(0.7109)
# tensor(0.6172)
# tensor(0.6562)
# tensor(0.6562)
# tensor(0.6641)
# Acu Train: 0.6671907305717468
# Acu valid: 0.5744813680648804
# tensor(0.6328)
# tensor(0.7266)
# tensor(0.6875)
# tensor(0.6797)
# tensor(0.6953)
# tensor(0.7266)
# tensor(0.7031)
# tensor(0.6484)
# tensor(0.7109)
# tensor(0.6094)
# Acu Train: 0.6699316501617432
# Acu valid: 0.5777913331985474
# tensor(0.7031)
# tensor(0.7109)
# tensor(0.6797)
# tensor(0.6484)
# tensor(0.6953)
# tensor(0.6016)
# tensor(0.6250)
# tensor(0.6797)
# tensor(0.7578)
# tensor(0.6953)
# Acu Train: 0.6785954833030701
# Acu valid: 0.5790597200393677
# tensor(0.6719)
# tensor(0.6172)
# tensor(0.7031)
# tensor(0.6875)
# tensor(0.6641)
# tensor(0.7031)
# tensor(0.6719)
# tensor(0.7188)
# tensor(0.6484)
# tensor(0.6016)
# Acu Train: 0.6846078634262085
# Acu valid: 0.5784904956817627
# tensor(0.7031)
# tensor(0.7578)
# tensor(0.6875)
# tensor(0.7500)
# tensor(0.6562)
# tensor(0.7031)
# tensor(0.6797)
# tensor(0.6953)
# tensor(0.7266)
# tensor(0.6875)
# Acu Train: 0.691041886806488
# Acu valid: 0.5794875025749207
# tensor(0.6328)
# tensor(0.6562)
# tensor(0.6484)
# tensor(0.7031)
# tensor(0.6484)
# tensor(0.7109)
# tensor(0.6484)
# tensor(0.7188)
# tensor(0.6484)
# tensor(0.6250)
# Acu Train: 0.6931061148643494
# Acu valid: 0.5750027298927307
# tensor(0.6875)
# tensor(0.7188)
# tensor(0.6719)
# tensor(0.7031)
# tensor(0.6875)
# tensor(0.7266)
# tensor(0.7500)
# tensor(0.6719)
# tensor(0.7266)
# tensor(0.7109)
# Acu Train: 0.6999368071556091
# Acu valid: 0.5822224020957947
# tensor(0.7109)
# tensor(0.7422)
# tensor(0.7656)
# tensor(0.7031)
# tensor(0.7188)
# tensor(0.7031)
# tensor(0.6641)
# tensor(0.7266)
# tensor(0.7109)
# tensor(0.6719)
# Acu Train: 0.7055276036262512
# Acu valid: 0.5813441276550293
# tensor(0.7031)
# tensor(0.6953)
# tensor(0.7344)
# tensor(0.6562)
# tensor(0.6875)
# tensor(0.6406)
# tensor(0.6797)
# tensor(0.7734)
# tensor(0.7969)
# tensor(0.7422)
# Acu Train: 0.6979616284370422
# Acu valid: 0.5754085183143616
# tensor(0.7500)
# tensor(0.7266)
# tensor(0.6797)
# tensor(0.6797)
# tensor(0.6562)
# tensor(0.6953)
# tensor(0.7656)
# tensor(0.7109)
# tensor(0.6875)
# tensor(0.7109)
# Acu Train: 0.7078566551208496
# Acu valid: 0.5805928111076355
# tensor(0.6953)
# tensor(0.6875)
# tensor(0.6875)
# tensor(0.7734)
# tensor(0.7344)
# tensor(0.6641)
# tensor(0.6641)
# tensor(0.7812)
# tensor(0.6953)
# tensor(0.6875)
# Acu Train: 0.713062584400177
# Acu valid: 0.5824061632156372
# tensor(0.8125)
# tensor(0.7031)
# tensor(0.7656)
# tensor(0.7422)
# tensor(0.7188)
# tensor(0.7188)
# tensor(0.5859)
# tensor(0.7422)
# tensor(0.7109)
# tensor(0.7031)
# Acu Train: 0.7129852175712585
# Acu valid: 0.584562361240387
# tensor(0.7109)
# tensor(0.6172)
# tensor(0.7031)
# tensor(0.7266)
# tensor(0.7578)
# tensor(0.7188)
# tensor(0.7500)
# tensor(0.7031)
# tensor(0.7656)
# tensor(0.7656)
# Acu Train: 0.7171075344085693
# Acu valid: 0.5809003114700317
# tensor(0.7812)
# tensor(0.7031)
# tensor(0.6719)
# tensor(0.7969)
# tensor(0.7578)
# tensor(0.7812)
# tensor(0.7109)
# tensor(0.7734)
# tensor(0.7891)
# tensor(0.7500)
# Acu Train: 0.7250153422355652
# Acu valid: 0.5779643058776855
# tensor(0.7656)
# tensor(0.7656)
# tensor(0.7969)
# tensor(0.7031)
# tensor(0.7734)
# tensor(0.6641)
# tensor(0.7266)
# tensor(0.7656)
# tensor(0.6875)
# tensor(0.6953)
# Acu Train: 0.7260689735412598
# Acu valid: 0.5791485905647278
# tensor(0.6719)
# tensor(0.7500)
# tensor(0.7344)
# tensor(0.7109)
# tensor(0.7188)
# tensor(0.6406)
# tensor(0.7344)
# tensor(0.7422)
# tensor(0.7344)
# tensor(0.7266)
# Acu Train: 0.7308010458946228
# Acu valid: 0.5680115222930908
# tensor(0.6875)
# tensor(0.6953)
# tensor(0.8438)
# tensor(0.7188)
# tensor(0.7188)
# tensor(0.7812)
# tensor(0.7422)
# tensor(0.7266)
# tensor(0.7500)
# tensor(0.7266)
# Acu Train: 0.735621452331543
# Acu valid: 0.5816423296928406
# tensor(0.7656)
# tensor(0.6875)
# tensor(0.7344)
# tensor(0.6797)
# tensor(0.7656)
# tensor(0.6875)
# tensor(0.6953)
# tensor(0.7109)
# tensor(0.7500)
# tensor(0.8203)
# Acu Train: 0.7378615736961365
# Acu valid: 0.5809382796287537
# tensor(0.7812)
# tensor(0.6953)
# tensor(0.7344)
# tensor(0.6797)
# tensor(0.7734)
# tensor(0.8125)
# tensor(0.6875)
# tensor(0.7656)
# tensor(0.7109)
# tensor(0.7656)
# Acu Train: 0.7458727955818176
# Acu valid: 0.5831499695777893
# tensor(0.7969)
# tensor(0.7188)
# tensor(0.7500)
# tensor(0.7266)
# tensor(0.6875)
# tensor(0.8203)
# tensor(0.7500)
# tensor(0.7734)
# tensor(0.7578)
# tensor(0.7266)
# Acu Train: 0.7482686638832092
# Acu valid: 0.5771892666816711
# tensor(0.7109)
# tensor(0.7891)
# tensor(0.7578)
# tensor(0.7266)
# tensor(0.7344)
# tensor(0.7656)
# tensor(0.7188)
# tensor(0.7109)
# tensor(0.6875)
# tensor(0.7500)
# Acu Train: 0.7483717799186707
# Acu valid: 0.5824156403541565
# tensor(0.7578)
# tensor(0.6875)
# tensor(0.7656)
# tensor(0.6719)
# tensor(0.7344)
# tensor(0.8203)
# tensor(0.7266)
# tensor(0.7422)
# tensor(0.7344)
# tensor(0.7812)
# Acu Train: 0.7516239881515503
# Acu valid: 0.5830942988395691
# tensor(0.)
# tensor(0.2891)
# tensor(0.2891)
# tensor(0.3750)
# tensor(0.4844)
# tensor(0.4062)
# tensor(0.4297)
# tensor(0.5625)
# tensor(0.5703)
# tensor(0.5156)
# Acu Train: 0.4052617847919464
# Acu valid: 0.46152636408805847
# tensor(0.5000)
# tensor(0.5469)
# tensor(0.5312)
# tensor(0.5078)
# tensor(0.6406)
# tensor(0.5781)
# tensor(0.5391)
# tensor(0.6094)
# tensor(0.6172)
# tensor(0.5781)
# Acu Train: 0.5830357074737549
# Acu valid: 0.5188912749290466
# tensor(0.6172)
# tensor(0.6719)
# tensor(0.6328)
# tensor(0.6328)
# tensor(0.6641)
# tensor(0.6797)
# tensor(0.6797)
# tensor(0.6250)
# tensor(0.6641)
# tensor(0.6953)
# Acu Train: 0.6725897192955017
# Acu valid: 0.5175804495811462
# tensor(0.6875)
# tensor(0.6719)
# tensor(0.7422)
# tensor(0.6562)
# tensor(0.7109)
# tensor(0.7812)
# tensor(0.7578)
# tensor(0.7188)
# tensor(0.6875)
# tensor(0.7109)
# Acu Train: 0.7300769090652466
# Acu valid: 0.5229390859603882
# tensor(0.8047)
# tensor(0.7812)
# tensor(0.7422)
# tensor(0.7656)
# tensor(0.7578)
# tensor(0.7578)
# tensor(0.7891)
# tensor(0.7969)
# tensor(0.7734)
# tensor(0.7656)
# Acu Train: 0.7730599641799927
# Acu valid: 0.5214613676071167
# tensor(0.8203)
# tensor(0.7812)
# tensor(0.7812)
# tensor(0.7969)
# tensor(0.7656)
# tensor(0.8125)
# tensor(0.7812)
# tensor(0.8281)
# tensor(0.8125)
# tensor(0.8750)
# Acu Train: 0.806238055229187
# Acu valid: 0.5234922170639038
# tensor(0.8281)
# tensor(0.8281)
# tensor(0.8047)
# tensor(0.8203)
# tensor(0.8516)
# tensor(0.8359)
# tensor(0.8125)
# tensor(0.8438)
# tensor(0.7812)
# tensor(0.8516)
# Acu Train: 0.8326272964477539
# Acu valid: 0.5145639181137085
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.8672)
# tensor(0.9062)
# tensor(0.8516)
# tensor(0.7969)
# tensor(0.8359)
# tensor(0.8750)
# tensor(0.7891)
# tensor(0.8750)
# Acu Train: 0.8524208664894104
# Acu valid: 0.514663577079773
# tensor(0.8672)
# tensor(0.9141)
# tensor(0.8828)
# tensor(0.8828)
# tensor(0.9062)
# tensor(0.8047)
# tensor(0.8359)
# tensor(0.8984)
# tensor(0.8828)
# tensor(0.8672)
# Acu Train: 0.8686951398849487
# Acu valid: 0.5114469528198242
# tensor(0.8984)
# tensor(0.8438)
# tensor(0.9141)
# tensor(0.8516)
# tensor(0.8359)
# tensor(0.8359)
# tensor(0.8125)
# tensor(0.8516)
# tensor(0.8906)
# tensor(0.8672)
# Acu Train: 0.8807626366615295
# Acu valid: 0.5147315859794617
# tensor(0.9531)
# tensor(0.8672)
# tensor(0.8672)
# tensor(0.8359)
# tensor(0.9062)
# tensor(0.9141)
# tensor(0.8594)
# tensor(0.8984)
# tensor(0.9219)
# tensor(0.8828)
# Acu Train: 0.8906316161155701
# Acu valid: 0.5098791718482971
# tensor(0.9375)
# tensor(0.9375)
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.8750)
# tensor(0.9297)
# tensor(0.8828)
# tensor(0.8516)
# tensor(0.9062)
# tensor(0.8828)
# Acu Train: 0.8985966444015503
# Acu valid: 0.5106715559959412
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.9062)
# tensor(0.8594)
# tensor(0.8750)
# tensor(0.9297)
# tensor(0.9062)
# tensor(0.8594)
# Acu Train: 0.9048036932945251
# Acu valid: 0.5083363056182861
# tensor(0.9297)
# tensor(0.9297)
# tensor(0.8906)
# tensor(0.8984)
# tensor(0.9141)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.8828)
# Acu Train: 0.9105559587478638
# Acu valid: 0.5094966888427734
# tensor(0.9531)
# tensor(0.9453)
# tensor(0.8984)
# tensor(0.8750)
# tensor(0.8906)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.9062)
# tensor(0.8984)
# tensor(0.8984)
# Acu Train: 0.9140311479568481
# Acu valid: 0.5082588195800781
# tensor(0.9531)
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9375)
# tensor(0.8906)
# tensor(0.9062)
# tensor(0.9297)
# tensor(0.9141)
# tensor(0.8828)
# tensor(0.8984)
# Acu Train: 0.9177221655845642
# Acu valid: 0.5085221529006958
# tensor(0.9375)
# tensor(0.9141)
# tensor(0.9219)
# tensor(0.8906)
# tensor(0.9219)
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9453)
# tensor(0.8984)
# Acu Train: 0.9201045632362366
# Acu valid: 0.5030492544174194
# tensor(0.9609)
# tensor(0.9297)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.9375)
# tensor(0.9609)
# tensor(0.9219)
# tensor(0.8906)
# tensor(0.8750)
# Acu Train: 0.9216893911361694
# Acu valid: 0.5079828500747681
# tensor(0.9141)
# tensor(0.9297)
# tensor(0.8594)
# tensor(0.8906)
# tensor(0.8984)
# tensor(0.8984)
# tensor(0.9375)
# tensor(0.9531)
# tensor(0.9219)
# tensor(0.8359)
# Acu Train: 0.9243090748786926
# Acu valid: 0.5047693848609924
# tensor(0.8984)
# tensor(0.9453)
# tensor(0.9297)
# tensor(0.9609)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.8672)
# tensor(0.9688)
# tensor(0.9297)
# tensor(0.8984)
# Acu Train: 0.9239991307258606
# Acu valid: 0.5072550773620605
# tensor(0.9453)
# tensor(0.9609)
# tensor(0.9688)
# tensor(0.9219)
# tensor(0.9219)
# tensor(0.9531)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.9062)
# Acu Train: 0.925175666809082
# Acu valid: 0.5037769675254822
# tensor(0.9531)
# tensor(0.9531)
# tensor(0.9297)
# tensor(0.9609)
# tensor(0.9531)
# tensor(0.8750)
# tensor(0.9375)
# tensor(0.9219)
# tensor(0.8672)
# tensor(0.9375)
# Acu Train: 0.9254117012023926
# Acu valid: 0.5027749538421631
# tensor(0.9297)
# tensor(0.9375)
# tensor(0.9453)
# tensor(0.9141)
# tensor(0.9453)
# tensor(0.9219)
# tensor(0.9375)
# tensor(0.9531)
# tensor(0.9375)
# tensor(0.9688)
# Acu Train: 0.925973653793335
# Acu valid: 0.5004367828369141
# tensor(0.8906)
# tensor(0.9375)
# tensor(0.9453)
# tensor(0.9531)
# tensor(0.8750)
# tensor(0.9062)
# tensor(0.9297)
# tensor(0.9453)
# tensor(0.9453)
# tensor(0.8906)
# Acu Train: 0.9257212281227112
# Acu valid: 0.504041850566864
# tensor(0.9375)
# tensor(0.9375)
# tensor(0.9609)
# tensor(0.9062)
# tensor(0.9453)
# tensor(0.9375)
# tensor(0.9375)
# tensor(0.8594)
# tensor(0.8906)
# tensor(0.9141)
# Acu Train: 0.9245270490646362
# Acu valid: 0.5029765963554382
# tensor(0.9297)
# tensor(0.9531)
# tensor(0.9609)
# tensor(0.9141)
# tensor(0.9062)
# tensor(0.9297)
# tensor(0.9609)
# tensor(0.8516)
# tensor(0.9297)
# tensor(0.9219)
# Acu Train: 0.9242950677871704

# %%
from google.colab import runtime
runtime.unassign()
